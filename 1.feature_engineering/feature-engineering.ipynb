# %% [markdown]
# # Import Libraries

# %%
from datetime import datetime, timedelta

import numpy as np
import pandas as pd
from pathlib import Path
import polars as pl

import torch
import torch.nn.functional as F

import warnings

warnings.filterwarnings('ignore')
pd.set_option('display.max_columns', 1000)

#Logging
import logging

# Get logger
logger = logging.getLogger(__name__)
logger.setLevel(logging.DEBUG)
file_handler = logging.FileHandler('logs.log')

# Set log format
formatter = logging.Formatter('[%(asctime)s][%(levelname)s] %(message)s')
file_handler.setFormatter(formatter)
logger.addHandler(file_handler)

# Settings to display log on notebook
stream_handler = logging.StreamHandler()
stream_handler.setFormatter(formatter)
logger.addHandler(stream_handler)
# Out:
# <style type='text/css'>
# .datatable table.frame { margin-bottom: 0; }
# .datatable table.frame thead { border-bottom: none; }
# .datatable table.frame tr.coltypes td {  color: #FFFFFF;  line-height: 6px;  padding: 0 0.5em;}
# .datatable .bool    { background: #DDDD99; }
# .datatable .object  { background: #565656; }
# .datatable .int     { background: #5D9E5D; }
# .datatable .float   { background: #4040CC; }
# .datatable .str     { background: #CC4040; }
# .datatable .time    { background: #40CC40; }
# .datatable .row_index {  background: var(--jp-border-color3);  border-right: 1px solid var(--jp-border-color0);  color: var(--jp-ui-font-color3);  font-size: 9px;}
# .datatable .frame tbody td { text-align: left; }
# .datatable .frame tr.coltypes .row_index {  background: var(--jp-border-color0);}
# .datatable th:nth-child(2) { padding-left: 12px; }
# .datatable .hellipsis {  color: var(--jp-cell-editor-border-color);}
# .datatable .vellipsis {  background: var(--jp-layout-color0);  color: var(--jp-cell-editor-border-color);}
# .datatable .na {  color: var(--jp-cell-editor-border-color);  font-size: 80%;}
# .datatable .sp {  opacity: 0.25;}
# .datatable .footer { font-size: 9px; }
# .datatable .frame_dimensions {  background: var(--jp-border-color3);  border-top: 1px solid var(--jp-border-color0);  color: var(--jp-ui-font-color3);  display: inline-block;  opacity: 0.6;  padding: 1px 10px 1px 5px;}
# </style>

# %% [markdown]
# # Data Load

# %%
TRAIN_DIR = Path('/home/data/train_large')
TEST_DIR = Path('/home/data/ebnerd_testset')

# %%
trn_behaviors = pl.read_parquet(TRAIN_DIR/'train'/'behaviors.parquet')
trn_history = pl.read_parquet(TRAIN_DIR/'train'/'history.parquet')

val_behaviors = pl.read_parquet(TRAIN_DIR/'validation'/'behaviors.parquet')
val_history = pl.read_parquet(TRAIN_DIR/'validation'/'history_extended.parquet')

articles = pl.read_parquet(TRAIN_DIR/'articles.parquet')

# %% [markdown]
# # Extend Validation/Test History Files

# %%
_trn_history = trn_history.explode(["impression_time_fixed", "scroll_percentage_fixed", "article_id_fixed", "read_time_fixed"])
_val_history = val_history.explode(["impression_time_fixed", "scroll_percentage_fixed", "article_id_fixed", "read_time_fixed"])

val_history_extended = pl.concat([
    _trn_history.filter(pl.col("user_id").is_in(set(val_history["user_id"]) & set(trn_history["user_id"]))),
    _val_history
])
val_history = val_history_extended.sort(
    ["user_id", "impression_time_fixed"]
).unique().groupby("user_id").agg(["impression_time_fixed", "scroll_percentage_fixed", "article_id_fixed", "read_time_fixed"])

val_history.write_parquet(TRAIN_DIR/'validation'/"history_extended.parquet")

# %%
trn_behaviors = pl.read_parquet(TRAIN_DIR/'train'/'behaviors.parquet')
trn_history = pl.read_parquet(TRAIN_DIR/'train'/'history.parquet')

val_behaviors = pl.read_parquet(TRAIN_DIR/'validation'/'behaviors.parquet')
val_history = pl.read_parquet(TRAIN_DIR/'validation'/'history.parquet')

test_behaviors = pl.read_parquet(TEST_DIR/'test'/'behaviors.parquet')
test_history = pl.read_parquet(TEST_DIR/'test'/'history.parquet')

articles = pl.read_parquet(TRAIN_DIR/'articles.parquet')

_trn_history = trn_history.explode(["impression_time_fixed", "scroll_percentage_fixed", "article_id_fixed", "read_time_fixed"])
_val_history = val_history.explode(["impression_time_fixed", "scroll_percentage_fixed", "article_id_fixed", "read_time_fixed"])
_test_history = test_history.explode(["impression_time_fixed", "scroll_percentage_fixed", "article_id_fixed", "read_time_fixed"])

test_history_extended = pl.concat([
    _trn_history.filter(pl.col("user_id").is_in(set(test_history["user_id"]) & set(trn_history["user_id"]))),
    _val_history.filter(pl.col("user_id").is_in(set(test_history["user_id"]) & set(val_history["user_id"]))),
    _test_history
])
test_history = test_history_extended.sort(
    ["user_id", "impression_time_fixed"]
).unique().groupby("user_id").agg(["impression_time_fixed", "scroll_percentage_fixed", "article_id_fixed", "read_time_fixed"])

# %% [markdown]
# # Create Dataset

# %%
def get_target_df(
        df: pl.DataFrame
) -> pl.DataFrame:
    '''
    Create target_df. The target column is "is_clicked"
    '''
    
    df = df.with_columns(
    pl.col("article_ids_inview").apply(lambda x: len(x)).alias("count_article_ids_inview"),
    )

    # Explode article_ids_inview
    df = df.explode("article_ids_inview")

    # If article_ids_inview is in article_ids_clicked, then 1, otherwise 0
    df = df.with_columns(
        pl.when(pl.col("article_ids_inview").is_in(pl.col("article_ids_clicked")))
        .then(1)
        .otherwise(0)
        .alias("is_clicked")
    )

    # Delete columns that are not used
    df = df.drop(["article_ids_clicked","next_read_time","next_scroll_percentage","article_id"])

    # Change the name of article_ids_inview to article_id
    df = df.with_columns(pl.col("article_ids_inview").alias("article_id"))
    df = df.drop("article_ids_inview")

    # Calculate the rate of is_clicked
    is_clicked_rate = df.select("is_clicked").mean().to_pandas().iloc[0,0]
    logger.info(f'is_clicked_rate: {is_clicked_rate}')

    # Show the shape of df
    logger.info(f'df shape: {df.shape}')

    return df

# %% [markdown]
# # Feature Engineering

# %% [markdown]
# ### Inview Cooccurance Feature

# %%
def feat_inview_cooccur(
        df: pl.DataFrame, mode: str
) -> pl.DataFrame:
    '''
    Create features that show the number of co-visits between articles.
    '''

    _len = len(df)

    # Load the pre-computed co-visit counts
    df_covisit_count = pl.read_parquet(f'/home/data/inview_cooccur/{mode}_covisit_count.parquet')

    tmp_df = df.select(['impression_id','user_id','article_id'])

    # Remove impression_id = 0
    tmp_df = tmp_df.filter(pl.col('impression_id') != 0)

    tmp_df = tmp_df.join(tmp_df, on = ['impression_id','user_id'],how='left')

    tmp_df = tmp_df.join(df_covisit_count, on = ['article_id','article_id_right'],how='left')

    feat_df = tmp_df.groupby(['impression_id','user_id','article_id']).agg(
    pl.sum('cooccur_count').alias('cooccur_count_sum'),
    pl.mean('cooccur_count').alias('cooccur_count_mean'),
    pl.max('cooccur_count').alias('cooccur_count_max'),
    pl.min('cooccur_count').alias('cooccur_count_min'),
    pl.std('cooccur_count').alias('cooccur_count_std'),
    )

    # Normalize each feature by the maximum value for each impression_id
    feat_df = feat_df.join(
        feat_df.groupby('impression_id').agg(
            pl.max('cooccur_count_sum').alias('cooccur_count_sum_max'),
            pl.max('cooccur_count_mean').alias('cooccur_count_mean_max'),
            pl.max('cooccur_count_max').alias('cooccur_count_max_max'),
            pl.max('cooccur_count_min').alias('cooccur_count_min_max'),
            pl.max('cooccur_count_std').alias('cooccur_count_std_max'),
        ),
        on='impression_id'
    )
    
    # Normalize each feature by the maximum value for each impression_id
    feat_df = feat_df.with_columns(
        (pl.col('cooccur_count_sum')/pl.col('cooccur_count_sum_max')).alias('cooccur_count_sum_norm'),
        (pl.col('cooccur_count_mean')/pl.col('cooccur_count_mean_max')).alias('cooccur_count_mean_norm'),
        (pl.col('cooccur_count_max')/pl.col('cooccur_count_max_max')).alias('cooccur_count_max_norm'),
        (pl.col('cooccur_count_min')/pl.col('cooccur_count_min_max')).alias('cooccur_count_min_norm'),
        (pl.col('cooccur_count_std')/pl.col('cooccur_count_std_max')).alias('cooccur_count_std_norm'),
    )

    feat_df = feat_df.drop(['cooccur_count_sum_max','cooccur_count_mean_max','cooccur_count_max_max','cooccur_count_min_max','cooccur_count_std_max'])
    df = df.join(feat_df, on = ['impression_id','user_id','article_id'],how='left')

    assert _len == len(df)

    return df

# %% [markdown]
# ### History Click Counts

# %%
def feat_clicked_history_count(
        df: pl.DataFrame, 
        df_history: pl.DataFrame
) -> pl.DataFrame:
    '''
    Add features that show the number of times an article has been clicked in the past.
    '''
    _len = len(df)

    user_article = df.select(['article_id','user_id','impression_time'])

    df_history = df_history.explode(['impression_time_fixed','scroll_percentage_fixed','article_id_fixed','read_time_fixed'])
    df_history.columns = ['user_id','impression_time_history','scroll_percentage_history','article_id','read_time_history']

    # Get the combination of user_id and article_id_fixed
    df_history = df_history.join(user_article, on=['user_id','article_id'], how='inner')

    feat_df = df_history.groupby(['user_id','article_id']).agg(
        # Count the number of times the article has been read
        pl.count('impression_time_history').alias('article_read_count'),
        # Get the latest time the article was read
        pl.max('impression_time_history').alias('article_last_read_time'),
    )

    df = df.join(feat_df, on=['user_id','article_id'], how='left')

    # Convert the difference between last_read_time and impression_time to X hours
    df = df.with_columns(
        ((pl.col('impression_time') - pl.col('article_last_read_time')) / timedelta(hours=1)).alias('article_last_read_time_diff')
    ).drop('article_last_read_time')

    # Fill the missing values in read_count, max_scroll_percentage, max_read_time with 0
    df = df.with_columns([
        pl.col("article_read_count").fill_null(0),
    ])

    assert _len == len(df)
    
    return df

# %%
def feat_clicked_history_count_by_article(
        df: pl.DataFrame, 
        df_history: pl.DataFrame
) -> pl.DataFrame:
    '''
    Add features that show the number of times an article has been clicked in the past.
    '''
    _len = len(df)

    user_article = df.select(['article_id','impression_time'])

    df_history = df_history.explode(['impression_time_fixed','scroll_percentage_fixed','article_id_fixed','read_time_fixed'])
    df_history.columns = ['user_id','impression_time_history','scroll_percentage_history','article_id','read_time_history']

    # Get the combination of user_id and article_id_fixed
    df_history = df_history.join(user_article, on=['article_id'], how='inner')

    feat_df = df_history.groupby(['article_id']).agg(
        # Count the number of times the article has been read
        pl.count('impression_time_history').alias('article_read_count_v2'),
    )

    df = df.join(feat_df, on=['article_id'], how='left')
    
    assert _len == len(df)
    
    return df

# %%
def load_vector_df(path_str: str) -> pl.DataFrame:
    '''
    Load the vector. The vector is provided by the original data.
    '''
    _vec = pd.read_parquet(path_str)

    logger.info(f'_vec columns : {_vec.columns}')

    col_name = _vec.columns[-1]

    df_vec = _vec.apply(lambda row: pd.Series(row[col_name]), axis=1)
    df_vec.columns = [f'vector_{i}' for i in range(df_vec.shape[1])]

    df_vec['article_id'] = _vec['article_id']

    df_vec = pl.from_pandas(df_vec)

    logger.info(f'{path_str} shape: {df_vec.shape}')

    return df_vec

def load_my_vector_df(path_str: str) -> pl.DataFrame:
    df_vec = pl.read_parquet(path_str)
    return df_vec
    

common_vec_dict = {
    'multilingual-e5-large-instruct':load_my_vector_df('/home/data/multilingual-e5-large-instruct/multilingual-e5-large-instruct_vec_df.parquet')
}

my_vec_dict = {
    'item2vec':{
        'train':load_my_vector_df('/home/data/item2vec_1/train_item2vec.parquet'),
        'valid':load_my_vector_df('/home/data/item2vec_1/valid_item2vec.parquet'),
        'test':load_my_vector_df('/home/data/item2vec_1/test_item2vec.parquet'),
    }
}

# %%
def feat_clicked_cossim(
        df: pl.DataFrame,
        df_history: pl.DataFrame,
        df_vec: pl.DataFrame,
        cossim_name: str,
        type: str='mean',
        window: int=1,
) -> pl.DataFrame:
    '''
    type:
     mean: Cosine similarity between the average vector of the user's past actions and the article vector
     scroll_mean: Cosine similarity between the average vector of the user's past actions and the article vector
     read_time_mean: Cosine similarity between the average vector of the user's past actions and the article vector
    '''

    _len = len(df)

    df_history = df_history.explode(['impression_time_fixed','scroll_percentage_fixed','article_id_fixed','read_time_fixed'])
    df_history.columns = ['user_id','impression_time_history','scroll_percentage_history','article_id','read_time_history']
    df_history = df_history.fill_null(0)

    user_article = df.select(['article_id','user_id','impression_time','impression_id'])

    df_history = df_history.join(df_vec, on='article_id', how='left')
    vec_cols = [col for col in df_history.columns if 'vector' in col]

    # User embeddings
    # How many past actions to consider with the window (if window is 0, use the entire history)
    if window > 0:
        df_history = df_history.sort('impression_time_history', descending=True).groupby('user_id').head(window)

    if type == 'mean':
        user_emb = df_history.groupby('user_id').agg(
            *[pl.mean(col).alias(col) for col in vec_cols]
        ) # Simple mean of the latest article emb
    elif type == 'max':
        user_emb = df_history.groupby('user_id').agg(
            *[pl.max(col).alias(col) for col in vec_cols]
        ) # Simple max of the latest article emb
    elif type == 'min':
        user_emb = df_history.groupby('user_id').agg(
            *[pl.min(col).alias(col) for col in vec_cols]
        ) # Simple min of the latest article emb
    elif type == 'scroll_mean':
        # Scroll_percentage based mean of the latest article emb
        for col in vec_cols:
            df_history = df_history.with_columns(
                (pl.col(col) * pl.col('scroll_percentage_history') / 100).alias(col)
            )
        user_emb = df_history.groupby('user_id').agg(
            *[pl.mean(col).alias(col) for col in vec_cols]
        )
    elif type == 'read_time_mean':
        # Read time based mean of the latest article emb
        user_read_time = df_history.groupby('user_id').agg(
            pl.sum('read_time_history').alias('user_read_time')
        )
        df_history = df_history.join(user_read_time, on='user_id', how='left')
        df_history = df_history.with_columns(
            (pl.col('read_time_history') / pl.col('user_read_time')).alias('read_time_percentage')
        )
        for col in vec_cols:
            df_history = df_history.with_columns(
                (pl.col(col) * pl.col('read_time_percentage')).alias(col)
            )
        user_emb = df_history.groupby('user_id').agg(
            *[pl.mean(col).alias(col) for col in vec_cols]
        )
    
    user_emb.columns = [f'user_{col}' if col != 'user_id' else col for col in user_emb.columns]

    # Article embeddings
    article_emb = df_vec.clone()
    article_emb.columns = [f'article_{col}' if col != 'article_id' else col for col in article_emb.columns]

    # Join user and article embeddings
    user_article = user_article.join(
    user_emb, on='user_id', how='left').join(
        article_emb, on='article_id', how='left')

    # Calculate cosine similarities
    user_vec = user_article.select([col for col in user_article.columns if 'user_vec' in col]).to_numpy()
    article_vec = user_article.select([col for col in user_article.columns if 'article_vec' in col]).to_numpy()

    user_vec = torch.tensor(user_vec)
    article_vec = torch.tensor(article_vec)

    similarity = F.cosine_similarity(
        user_vec, article_vec, dim=1)
    
    # Add as a feature
    user_article = user_article.with_columns(
        pl.Series(similarity.numpy()).alias(cossim_name)
    )

    feat_df = user_article.select(['user_id','article_id','impression_id',cossim_name])

    df = df.join(feat_df, on=['user_id','article_id','impression_id'], how='left')

    assert _len == len(df)

    return df

# %%
def feat_clicked_category_cossim(
        df: pl.DataFrame,
        df_history: pl.DataFrame,
        df_vec: pl.DataFrame,
        cossim_name: str,
        type: str='mean',
        window: int=1,
) -> pl.DataFrame:
    '''
    type:
     mean: Cosine similarity between the average vector of the user's past actions and the article vector
     scroll_mean: Cosine similarity between the average vector of the user's past actions and the article vector
     read_time_mean: Cosine similarity between the average vector of the user's past actions and the article vector
    '''
    _len = len(df)

    df_history = df_history.explode(['impression_time_fixed','scroll_percentage_fixed','article_id_fixed','read_time_fixed'])
    df_history.columns = ['user_id','impression_time_history','scroll_percentage_history','article_id','read_time_history']
    df_history = df_history.fill_null(0)
    df_history = df_history.join(articles.select(['article_id', 'category']), how='left', on='article_id')

    user_article = df.select(['article_id','user_id','category','impression_time','impression_id'])

    df_history = df_history.join(df_vec, on='article_id', how='left')
    vec_cols = [col for col in df_history.columns if 'vector' in col]

    # User embeddings
    # How many past actions to consider with the window (if window is 0, use the entire history)
    if window > 0:
        df_history = df_history.sort('impression_time_history',descending=True
                                     ).groupby(['user_id', 'category']).head(window)

    if type == 'mean':
        user_emb = df_history.groupby(['user_id', 'category']).agg(
            *[pl.mean(col).alias(col) for col in vec_cols]
        )

    elif type == 'min':
        user_emb = df_history.groupby(['user_id', 'category']).agg(
            *[pl.min(col).alias(col) for col in vec_cols]
        )
        
    elif type == 'max':
        user_emb = df_history.groupby(['user_id', 'category']).agg(
            *[pl.max(col).alias(col) for col in vec_cols]
        )

    elif type == 'scroll_mean':
        for col in vec_cols:
            df_history = df_history.with_columns(
                (pl.col(col) * pl.col('scroll_percentage_history') / 100).alias(col)
            )
        user_emb = df_history.groupby(['user_id', 'category']).agg(
            *[pl.mean(col).alias(col) for col in vec_cols]
        )

    elif type == 'read_time_mean':
        user_read_time = df_history.groupby(['user_id', 'category']).agg(
            pl.sum('read_time_history').alias('user_read_time')
        )
        df_history = df_history.join(user_read_time, on=['user_id', 'category'], how='left')
        df_history = df_history.with_columns(
            (pl.col('read_time_history') / pl.col('user_read_time')).alias('read_time_percentage')
        )
        for col in vec_cols:
            df_history = df_history.with_columns(
                (pl.col(col) * pl.col('read_time_percentage')).alias(col)
            )

        user_emb = df_history.groupby(['user_id', 'category']).agg(
            *[pl.mean(col).alias(col) for col in vec_cols]
        )
    
    user_emb.columns = [f'user_{col}' if col not in ['user_id', 'category'] else col for col in user_emb.columns]


    # Article embeddings
    article_emb = df_vec.clone()
    article_emb.columns = [f'article_{col}' if col != 'article_id' else col for col in article_emb.columns]

    # Join user and article embeddings
    user_article = user_article.join(
    user_emb, on=['user_id', 'category'], how='left').join(
        article_emb, on='article_id', how='left')

    # Calculate cosine similarities
    user_vec = user_article.select([col for col in user_article.columns if 'user_vec' in col]).to_numpy()
    article_vec = user_article.select([col for col in user_article.columns if 'article_vec' in col]).to_numpy()

    user_vec = torch.tensor(user_vec)
    article_vec = torch.tensor(article_vec)


    similarity = F.cosine_similarity(
        user_vec, article_vec, dim=1)
    
    # Add as a feature
    user_article = user_article.with_columns(
        pl.Series(similarity.numpy()).alias(cossim_name)
    )

    feat_df = user_article.select(['user_id','category','article_id','impression_id',cossim_name])

    df = df.join(feat_df, on=['user_id','category','article_id','impression_id'], how='left')

    assert _len == len(df)

    return df

# %%
def add_cossim_individual_features(
        df: pl.DataFrame, 
        df_history: pl.DataFrame, 
        df_vec: pl.DataFrame, 
        cossim_name: str
) -> pl.DataFrame:
    """表示された記事について、過去にクリックされた記事との類似度に関する特徴量を生成。dfはターゲットdf。"""

    _len = len(df)

    df_history = df_history.explode(['impression_time_fixed','scroll_percentage_fixed','article_id_fixed','read_time_fixed'])
    df_history.columns = ['user_id','impression_time_history','scroll_percentage_history','article_id','read_time_history']
    df_history = df_history.fill_null(0).rename({"article_id": "past_article_id"})

    user_article = df.select(['article_id','user_id','impression_time','impression_id'])
    user_article = user_article.join(df_history.select(["user_id", "past_article_id"]), on="user_id")

    user_article_unique = user_article.unique(["article_id", "past_article_id"]).drop(["user_id", "impression_time", "impression_id"]) # 表示された記事と過去に表示された記事の組み合わせ

    #articleの表現
    article_emb = df_vec.clone()
    article_emb.columns = [f'article_{col}' if col != 'article_id' else col for col in article_emb.columns]

    #join
    user_article_unique = user_article_unique.join(
        article_emb, on='article_id', how='left') # 表示された記事にembを付与


    article_emb.columns = ["past_" + col if col != "article_id" else col for col in article_emb.columns]

    user_article_unique = user_article_unique.join(
        article_emb, left_on='past_article_id', right_on="article_id", how='left') # 過去の記事にembを付与

    article_vec = user_article_unique.select(
        [col for col in user_article_unique.columns if ('article_vec' in col) & ("past_article_vec" not in col)]
    ).to_numpy()

    past_article_vec = user_article_unique.select(
        [col for col in user_article_unique.columns if ("past_article_vec" in col)]
    ).to_numpy()

    article_vec = torch.tensor(article_vec)
    past_article_vec = torch.tensor(past_article_vec)

    similarity = F.cosine_similarity(
        article_vec, past_article_vec, dim=1) # article_vec, past_article_vecの行ベクトル同士で類似度を取る。

    article_similarities = pl.DataFrame(
        {
            "article_id": user_article_unique["article_id"],
            "past_article_id": user_article_unique["past_article_id"],
            "cossim": similarity.numpy()
        }
    )

    user_article = user_article.join(article_similarities, how="left", on=["article_id", "past_article_id"])

    features = user_article.groupby(["impression_id", "article_id"]).agg(
        pl.col("cossim").max().alias(f"{cossim_name}_max_cossim"),
        pl.col("cossim").min().alias(f"{cossim_name}_min_cossim"),
        pl.col("cossim").mean().alias(f"{cossim_name}_mean_cossim"),
        pl.col("cossim").median().alias(f"{cossim_name}_median_cossim"),
        pl.col("cossim").quantile(0.1).alias(f"{cossim_name}_quantile_q10_cossim"),
        pl.col("cossim").quantile(0.25).alias(f"{cossim_name}_quantile_q25_cossim"),
        pl.col("cossim").quantile(0.75).alias(f"{cossim_name}_quantile_q75_cossim"),
        pl.col("cossim").quantile(0.9).alias(f"{cossim_name}_quantile_q90_cossim"),
    )
    
    df = df.join(features, how="left", on=["impression_id", "article_id"])
    
    # 標準化処理は少し効くらしい。
    for col in [
        f"{cossim_name}_max_cossim",
        f"{cossim_name}_min_cossim",
        f"{cossim_name}_mean_cossim",
        f"{cossim_name}_median_cossim",
        f"{cossim_name}_quantile_q10_cossim",
        f"{cossim_name}_quantile_q25_cossim",
        f"{cossim_name}_quantile_q75_cossim",
        f"{cossim_name}_quantile_q90_cossim",
    ]:
            #impressionごとに最大値を1として基準化
        df = df.join(
            df.groupby('impression_id').agg(
                pl.max(col).alias(f'max_{col}'),
                pl.min(col).alias(f'min_{col}'),
            ), on='impression_id', how='left'
        )

        df = df.with_columns(
            ((pl.col(col) - pl.col(f'min_{col}')) / (pl.col(f'max_{col}') - pl.col(f'min_{col}'))).alias(f'{col}_norm')
        ).drop([f'max_{col}', f'min_{col}', col])

    return df

# %%
def feat_inview_cossim(
        df:pl.DataFrame,
        df_vec:pl.DataFrame,
        cossim_name:str,
):
        '''
        inviewでユーザーのベクトルを作成し、そのベクトルと記事のベクトルのコサイン類似度を計算する
        groupとして、user_id, session_id, impression_idを使う
        '''

        _len = len(df)

        #articleの表現
        article_emb = df_vec.clone()
        article_emb.columns = [f'article_{col}' if col != 'article_id' else col for col in article_emb.columns]

        #userの表現
        df_user = df.select(['impression_id','user_id','article_id','session_id']).clone()
        df_user = df_user.join(df_vec, on='article_id', how='left')
        vec_cols = [col for col in df_user.columns if 'vector' in col]

        for group_col in ['user_id','session_id','impression_id']:
            user_emb = df_user.groupby(group_col).agg(
                    *[pl.mean(col).alias(col) for col in vec_cols]
                    )
            user_emb.columns = [f'user_{col}' if col != group_col else col for col in user_emb.columns]

            #join
            user_article = df_user.join(
                    user_emb, on=group_col, how='left').join(
                    article_emb, on='article_id', how='left')
        
            #類似度
            user_vec = user_article.select([col for col in user_article.columns if 'user_vec' in col]).to_numpy()
            article_vec = user_article.select([col for col in user_article.columns if 'article_vec' in col]).to_numpy()

            user_vec = torch.tensor(user_vec)
            article_vec = torch.tensor(article_vec)

            similarity = F.cosine_similarity(
                    user_vec, article_vec, dim=1)
            
            #user_articleに特徴量として追加する
            user_article = user_article.with_columns(
                    pl.Series(similarity.numpy()).alias(f'{cossim_name}_{group_col}')
                    )
            
            #特徴量として追加
            feat_df = user_article.select(['impression_id','user_id','article_id',f'{cossim_name}_{group_col}'])

            df = df.join(feat_df, on=['impression_id','user_id','article_id'], how='left')

            assert _len == len(df)

        return df

# %% [markdown]
# ### Articleのシンプルな特徴量

# %%
def feat_article_simple(df,articles):
    _len = len(df)
    
    articles_numfeat = articles.select([
    'article_id','premium','published_time','total_inviews','total_pageviews','total_read_time',
    'sentiment_score','sentiment_label', 'image_ids'])
    
    articles_numfeat = articles_numfeat.with_columns(pl.col("image_ids").list.lengths().alias("number_of_images")).drop("image_ids")
    
    #sentiment_labelのPositive/Neutral/Negative別にカラムを持たせる（iwaiさん）→少し上がる
    articles_numfeat = articles_numfeat.with_columns(
            pl.when(pl.col('sentiment_label') == 'Positive').then(pl.col('sentiment_score')).otherwise(0).alias('article_label_positive_score'),
            pl.when(pl.col('sentiment_label') == 'Negative').then(pl.col('sentiment_score')).otherwise(0).alias('article_label_negative_score'),
            pl.when(pl.col('sentiment_label') == 'Neutral').then(pl.col('sentiment_score')).otherwise(0).alias('article_label_neutral_score')
    ).drop('sentiment_score','sentiment_label')
    df = df.join(articles_numfeat, on='article_id', how='left')

    #impression_timeとpublished_timeの差をX日に変換
    df = df.with_columns(
        ((pl.col('impression_time') - pl.col('published_time')) / timedelta(days=1)).alias('published_time_diff')
    ).drop('published_time')

    #total_inviews,total_pageviews,total_read_timeについて,impressionごとに最大値を1として基準化
    df = df.join(
        df.groupby('impression_id').agg(
            pl.max('total_inviews').alias('max_total_inviews'),
            pl.max('total_pageviews').alias('max_total_pageviews'),
            pl.max('total_read_time').alias('max_total_read_time')
        ), on='impression_id', how='left'
    )

    df = df.with_columns(
        (pl.col('total_inviews') / pl.col('max_total_inviews')).alias('total_inviews_norm'),
        (pl.col('total_pageviews') / pl.col('max_total_pageviews')).alias('total_pageviews_norm'),
        (pl.col('total_read_time') / pl.col('max_total_read_time')).alias('total_read_time_norm')
    ).drop(['max_total_inviews','max_total_pageviews','max_total_read_time'])

    #published_time_diffについて、impressionごとに最小値を1として基準化
    df = df.join(
        df.groupby('impression_id').agg(
            pl.min('published_time_diff').alias('min_published_time_diff')
        ), on='impression_id', how='left'
    )

    df = df.with_columns(
        (pl.col('published_time_diff') / pl.col('min_published_time_diff')).alias('published_time_diff_norm')
    ).drop('min_published_time_diff')


    #premiumもis_subscriberもtrueなら1、それ以外は0
    df = df.with_columns(
        pl.when(pl.col('premium') & pl.col('is_subscriber')).then(1).otherwise(0).alias('is_premium_subscriber')
    )

    df = df.join(articles.select(["article_id", "category"]), how="left", on="article_id")

    #assert
    assert _len == len(df)

    #logger.info(f'feat_article_simple shape: {df.shape}')

    return df

# %% [markdown]
# ### Userが最後に読んだ記事の時間とarticleのpublishされた時間

# %%
def feat_user_last_impression_publish_time_diff(
    df,df_history,articles
    ):

    shape = df.shape

    df_history = df_history.explode(['impression_time_fixed', 'scroll_percentage_fixed', 'article_id_fixed','read_time_fixed'])
    df_history.columns = ['user_id', 'impression_time_history', 'scroll_percentage_history', 'article_id','read_time_history']

    #user_idごとにimpression_time_historyの最大値を取得
    user_last_impression_time = df_history.groupby('user_id').agg(
        pl.max('impression_time_history').alias('user_last_impression_time')
    )

    df = df.join(
        user_last_impression_time, on='user_id', how='left'
        ).join(
            articles.select(['article_id','published_time']), on='article_id', how='left'
        )

    #user_last_impression_timeとpublished_timeの差
    df = df.with_columns(
        ((pl.col('user_last_impression_time') - pl.col('published_time')) / timedelta(days=1)).alias('user_last_impression_time-publish_time_diff')
    ).drop(['user_last_impression_time','published_time'])

    #shape.check
    assert df.shape[0] == shape[0]

    return df

# %% [markdown]
# ### Articleの人気特徴量

# %%
# modeはtrainとか。各時間帯におけるinview(表示数)
def feat_article_pop(df:pl.DataFrame,
                     mode:str,
                     df_pop_path:str = '/home/data/article_pop_inview/',
                     metacol:str=None):
    _len = len(df)

    #time_interval_list
    time_interval_list = ['1m','2m','3m','5m','10m','15m','20m','30m','1h','2h','3h','6h','12h','24h'] 

    for time_interval in time_interval_list:
        if not metacol:
            file_path = f'{df_pop_path}{mode}_article_pop_inview_{time_interval}.parquet'
        else:
            file_path = f'{df_pop_path}{mode}_article_pop_inview_{time_interval}_{metacol}.parquet'

        try:
            df_pop = load_my_vector_df(file_path)
        except:
            logger.warning(f'{file_path} not found')
            continue

        #rounded_inview
        df = df.with_columns(
            pl.col("impression_time").dt.truncate(time_interval).alias(f'rounded_{time_interval}_datetime')
        )

        if not metacol:
            df = df.join(df_pop, on=['article_id',f'rounded_{time_interval}_datetime'], how='left').drop(
                [f'rounded_{time_interval}_datetime']
            )
        else:
            df = df.join(df_pop, on=['article_id',f'rounded_{time_interval}_datetime',metacol], how='left').drop(
                [f'rounded_{time_interval}_datetime']
            )

        #impressionごとに最大値を1として基準化
        if not metacol:
            colname = f'rounded_{time_interval}_inview_count'
        else:
            colname = f'rounded_{time_interval}_inview_count_{metacol}'

        df = df.join(
            df.groupby('impression_id').agg(
                pl.max(colname).alias(f'max_{colname}')
            ), on='impression_id', how='left'
        )

        df = df.with_columns(
            (pl.col(colname) / pl.col(f'max_{colname}')).alias(f'{colname}_norm')
        ).drop(f'max_{colname}')

    assert _len == len(df)

    return df

# %% [markdown]
# ## 統計特徴量

# %%
# 雑に有力な特徴量について統計量を追加
def add_statistic(df):
    target_cols = ['total_inviews', 'total_pageviews', 'total_read_time', 'rounded_1m_inview_count', 'rounded_2m_inview_count',
                     'rounded_3m_inview_count','rounded_5m_inview_count','rounded_10m_inview_count','rounded_15m_inview_count','rounded_20m_inview_count',
                     'rounded_30m_inview_count','rounded_1h_inview_count','rounded_3h_inview_count','rounded_6h_inview_count','rounded_12h_inview_count','rounded_24h_inview_count',
                     'inview_count', 'past_inview_count', 'time_gap_to_next_inview_impression_time', 'time_gap_from_prev_inview_impression_time', 'published_time_diff'
                    ]

    # 統計量
    operations = ["max", "min", "mean", "median", "std", "skew", "kurtosis"]

    # グループごとの集計結果を保存するリスト
    aggregations = []

    # 各列ごとに集計操作を定義
    for col in target_cols:
        for op in operations:
            agg_expr = getattr(pl.col(col), op)().alias(f"{col}_{op}")
            aggregations.append(agg_expr)

    # user_id ごとに集計を実行
    df_agg = df.groupby("impression_id").agg(aggregations)
    df = df.join(df_agg, on="impression_id", how="left")
    
    # diff系を追加
    for col in target_cols:
        if col in ['total_read_time','total_inviews', 'total_pageviews']: #精度に悪影響そうなので除外
            continue

        for op in ["max", "mean", "median", "min"]:
            df = df.with_columns((pl.col(f"{col}_{op}") - pl.col(f"{col}")).alias(f"{col}_{op}-{col}"))
            df = df.with_columns((pl.col(f"{col}_{op}") / pl.col(f"{col}")).alias(f"{col}_{op}/{col}"))
    
    return df

# %% [markdown]
# ### 過去のカテゴリの比率

# %%
# ユーザーが過去に見たカテゴリに関する情報。効く
def add_past_category_ratios(df, df_history):

    df_history = df_history.explode(['impression_time_fixed','scroll_percentage_fixed','article_id_fixed','read_time_fixed'])
    df_history.columns = ['user_id','impression_time_history','scroll_percentage_history','article_id','read_time_history']
    df_history = df_history.fill_null(0)

    # Joining training history data with article data
    df_history_articles = df_history.join(articles, on='article_id', how='left')
    user_category_df = df_history_articles.groupby(["user_id", "category"]).count().rename({"count": "past_category_count"})

    user_category_df = user_category_df.with_columns(pl.col("past_category_count").max().over("user_id").alias("max_past_category_count_count"))
    user_category_df = user_category_df.with_columns((pl.col("past_category_count") / pl.col("max_past_category_count_count")).alias("past_category_ratio"))

    # df_history_articles_subcategory = df_history_articles.with_columns((1 / pl.col("subcategory").count().over(["user_id", "impression_time_history", "article_id"])).alias("subcategory_ratio"))
    # user_subcategory_df = df_history_articles_subcategory.groupby(["user_id", "subcategory"]).agg(pl.col("subcategory_ratio").sum().alias("past_subcategory_count"))
    # user_subcategory_df = user_subcategory_df.with_columns(pl.col("past_subcategory_count").max().over("user_id").alias("max_past_subcategory_count"))
    # user_subcategory_df = user_subcategory_df.with_columns((pl.col("past_subcategory_count") / pl.col("max_past_subcategory_count")).alias("past_subcategory_ratio"))

#     df = df.join(articles.select(["article_id", "category"]), on="article_id", how="left")
    df = df.join(user_category_df, on=["user_id", "category"], how="left")# .drop("category")
    # df = df.join(user_subcategory_df, on=["user_id", "subcategory"], how="left").drop("subcategory")

    return df

# %% [markdown]
# ### inviewのカウント特徴量

# %%
# inview回数に関する特徴量。いわゆるリークを含む（総表示回数や、次の表示など）。
def calculate_inview_counts(df):
    df = df.sort("impression_time")

    df = df.with_columns(
        [
            pl.col("impression_id").count().over(["user_id", "article_id"]).alias("inview_count"),
            pl.col("impression_id").cumcount().over(["user_id", "article_id"]).alias("past_inview_count")
        ]
    )
    
    df = df.with_columns([
        pl.col("impression_time").shift(1).over(["user_id", "article_id"]).alias("next_inview_impression_time"), # これは一つ前のprev?
        pl.col("impression_time").shift(-1).over(["user_id", "article_id"]).alias("prev_inview_impression_time") # これは一つ先のimp?
    ])

    df = df.with_columns(
        [
            ((pl.col("next_inview_impression_time") - pl.col("impression_time")) / timedelta(hours=1)).alias("time_gap_to_next_inview_impression_time"),
            ((pl.col("impression_time") - pl.col("prev_inview_impression_time")) / timedelta(hours=1)).alias("time_gap_from_prev_inview_impression_time"),
        ]
    ).drop(["next_inview_impression_time", "prev_inview_impression_time"])
    
    return df

# %% [markdown]
# ### あらいさんのcossim by category

# %%
# +0.003程度の効果あり。
# 現状、対象のカテゴリ：["device_type", "is_subscriber", "is_sso_user"]
# カテゴリの値で重み付平均をとってuser embを求めている。それとarticle のembのcossimを求める　
def add_cossim_by_category(behaviors_df, history_df, emb_df, cossim_name, cat_col):
    # weight
    cat_vals = behaviors_df[cat_col].unique().to_list()
    # print(f"cat_vals: {cat_vals}")
    cat_weight_df = behaviors_df.select(["user_id", cat_col])
    weight_cols = []
    for cat_val in cat_vals:
        cat_weight_df = cat_weight_df.with_columns((pl.col(cat_col)==cat_val).alias(f"{cat_col}__{cat_val}"))
        weight_cols.append(f"{cat_col}__{cat_val}")
    cat_weight_df = cat_weight_df.groupby("user_id").agg([pl.col(col).mean() for col in weight_cols]) # ユーザーごとの、カテゴリの各valueの割合

    # add user emb
    _history_df = history_df.join(
        cat_weight_df,
        on="user_id",
        how="left",
    )

    user_emb_df = _history_df.join(
        emb_df.rename({col: f"userx__{col}" for col in emb_df.columns if col != "article_id"}),
        on="article_id",
        how="left",
    )
    user_emb_cols = [col for col in user_emb_df.columns if "userx__" in col]

    # weighted cateogory emb
    weighted_emb = None
    for weight_col in weight_cols:
        _weighted_emb = (user_emb_df.select(user_emb_cols) * user_emb_df[weight_col]).sum() / user_emb_df[weight_col].sum() # weight_colの値でhistoryの各user embの重み付平均をとる。
        if weighted_emb is not None:
            weighted_emb += cat_weight_df[weight_col] * _weighted_emb
        else:
            weighted_emb = cat_weight_df[weight_col] * _weighted_emb # その後、各ユーザのカテゴリの重みをかける。
    weighted_emb = pl.concat([cat_weight_df.select("user_id"), weighted_emb], how="horizontal")
    _behaviors_df = behaviors_df.join(weighted_emb, on="user_id", how="left")

    # article emb
    _behaviors_df = _behaviors_df.join(
        emb_df.rename({col: f"article__{col}" for col in emb_df.columns if col != "article_id"}),
        on="article_id",
        how="left",
    )
    article_emb_cols = [col for col in _behaviors_df.columns if "article__" in col]

    # cossim
    cossims = (_behaviors_df[user_emb_cols] * _behaviors_df[article_emb_cols]).sum(axis=1) / \
        (np.linalg.norm(_behaviors_df[user_emb_cols], axis=1) * np.linalg.norm(_behaviors_df[article_emb_cols], axis=1))
    behaviors_df = behaviors_df.with_columns(
        pl.lit(cossims).alias(cossim_name),
    )

    return behaviors_df

# %%
def normalize_rank_by_percentage(df):
    
    rank_cols = [
        'published_time_diff_rank',
        'total_inviews_norm_rank',
        'total_pageviews_norm_rank',
        'total_read_time_norm_rank',
        'rounded_1m_inview_count_rank',
        'rounded_2m_inview_count_rank',
        'rounded_3m_inview_count_rank',
        'rounded_5m_inview_count_rank',
        'rounded_10m_inview_count_rank',
        'rounded_15m_inview_count_rank',
        'rounded_20m_inview_count_rank',
        'rounded_30m_inview_count_rank',
        'rounded_1h_inview_count_rank',
        'rounded_3h_inview_count_rank',
        'rounded_6h_inview_count_rank',
        'rounded_12h_inview_count_rank',
        'rounded_24h_inview_count_rank',
        'inview_count_rank',
        'past_inview_count_rank',
        'time_gap_to_next_inview_impression_time_rank',
        'time_gap_from_prev_inview_impression_time_rank',
        'next_impression_id_mean_cossim_rank',
        'next_impression_id_min_cossim_rank',
        'next_impression_id_max_cossim_rank'
    ]

    impression_id_value_counts = df.groupby("impression_id").count().rename({"count": "impression_id_article_counts"})
    df = df.join(impression_id_value_counts, how="left", on="impression_id")

    expressions = [pl.col(col) / pl.col("impression_id_article_counts") for col in rank_cols]
    df = df.with_columns(expressions).drop("impression_id_article_counts")
    return df

# %%
def add_next_impression_id_cossim(
        df: pl.DataFrame, 
        df_vec: pl.DataFrame, 
        method: str = "mean"
) -> pl.DataFrame:
    
    colname = f"next_impression_id_{method}_cossim"

    df = df.sort(["session_id", "impression_time"], descending=[False, False])

    tmp_df = df.select(["impression_id", "session_id", "impression_time"])
    tmp_df = tmp_df.unique(["impression_id", "session_id", "impression_time"])
    tmp_df = tmp_df.sort(["session_id", "impression_time"], descending=[False, False])
    tmp_df = tmp_df.with_columns(pl.col("impression_id").shift(-1).over("session_id").alias("next_impression_id"))

    df = df.join(tmp_df.select(["impression_id", "next_impression_id"]), how="left", on="impression_id")

    df_next_impression_id = df.filter(df["impression_id"].is_in(set(df["next_impression_id"]))).select(["impression_id", "article_id"])
    df_next_impression_id = df_next_impression_id.join(df_vec, how="left", on="article_id")
    
    vec_cols = [col for col in df_next_impression_id.columns if 'vector' in col]
    
    if method == "mean":
        next_impression_id_emb = df_next_impression_id.groupby('impression_id').agg(
                *[pl.mean(col).alias(col) for col in vec_cols]
                )
    elif method == "min":
        next_impression_id_emb = df_next_impression_id.groupby('impression_id').agg(
                *[pl.min(col).alias(col) for col in vec_cols]
                )
    elif method == "max":
        next_impression_id_emb = df_next_impression_id.groupby('impression_id').agg(
                *[pl.max(col).alias(col) for col in vec_cols]
                )
    
    next_impression_id_emb.columns = [f'next_impression_id_{col}' if col != 'impression_id' else col for col in next_impression_id_emb.columns]

    df_current_impression_id = df.select(["impression_id", "article_id", "next_impression_id"])
    df_current_impression_id = df_current_impression_id.join(df_vec, how="left", on="article_id")

    df_current_impression_id.columns = [f'current_impression_id_{col}' if col not in ['article_id', 'impression_id', 'next_impression_id'] else col for col in df_current_impression_id.columns]

    df_crossed = df_current_impression_id.join(next_impression_id_emb, how="left", left_on=["next_impression_id"], right_on=["impression_id"])
    df_crossed = df_crossed.drop_nulls(["next_impression_id"])

    current_impression_id_vec = df_crossed.select([col for col in df_crossed.columns if 'current_impression_id_' in col]).to_numpy()
    next_impression_id_vec = df_crossed.select([col for col in df_crossed.columns if 'next_impression_id_' in col]).to_numpy()

    current_impression_id_vec = torch.tensor(current_impression_id_vec)
    next_impression_id_vec = torch.tensor(next_impression_id_vec)

    similarity = F.cosine_similarity(
            current_impression_id_vec, next_impression_id_vec, dim=1)

    #user_articleに特徴量として追加する
    df_crossed = df_crossed.with_columns(
            pl.Series(similarity.numpy()).alias(colname)
            )

    feat_df = df_crossed.select(['impression_id','article_id',colname])
    df = df.join(feat_df, how="left", on=["impression_id", "article_id"]).drop("next_impression_id")
    return df

# %%
def add_published_time_features(
        df: pl.DataFrame, 
        df_history: pl.DataFrame
) -> pl.DataFrame:
    _df_history = df_history.explode(
        [
            "impression_time_fixed", "scroll_percentage_fixed", "article_id_fixed", "read_time_fixed"
        ]
    ).rename({
        "impression_time_fixed": "impression_time", 
        "scroll_percentage_fixed": "scroll_percentage", 
        "article_id_fixed": "article_id", 
        "read_time_fixed": "read_time"
    })

    _df_history = _df_history.join(articles, how="left", on="article_id")
    _df_history = _df_history.with_columns(
            ((pl.col('impression_time') - pl.col('published_time')) / timedelta(days=1)).alias('published_time_diff')
    )
    _df_history = _df_history.groupby(["user_id"]).agg([
        pl.col("published_time_diff").mean().alias("mean_history_published_time_diff"),
        pl.col("published_time_diff").max().alias("max_history_published_time_diff"),
        pl.col("published_time_diff").min().alias("min_history_published_time_diff"),
        pl.col("published_time_diff").median().alias("median_history_published_time_diff"),
    ])
    
    df = df.join(_df_history, how="left", on="user_id")
    return df

# %% [markdown]
# ## Run Feature Engineering

# %%
def create_feature(
        df: pl.DataFrame,
        df_history: pl.DataFrame,
        mode: str = 'train',
        logging: bool = True
) -> pl.DataFrame:
    
    if logging:
        logger.info('start:feature_engineering')
        logger.info(f'df shape: {df.shape}')
        current_time = datetime.now()
                
    df = feat_clicked_history_count(df,df_history)
    df = feat_clicked_history_count_by_article(df,df_history)

    if logging:
        elapsed_seconds = (datetime.now() - current_time).seconds
        current_time = datetime.now()
        logger.info(f'clicked_history_count/elapsed_seconds: {elapsed_seconds}/df shape: {df.shape}')

    df = feat_inview_cooccur(df,mode)
    if logging:
        elapsed_seconds = (datetime.now() - current_time).seconds
        current_time = datetime.now()
        logger.info(f'inview_cooccur/elapsed_seconds: {elapsed_seconds}/df shape: {df.shape}')

    df = feat_article_simple(df,articles)
    if logging:
        elapsed_seconds = (datetime.now() - current_time).seconds
        current_time = datetime.now()
        logger.info(f'feat_article_simple/elapsed_seconds: {elapsed_seconds}/df shape: {df.shape}')

    df = feat_user_last_impression_publish_time_diff(df,df_history,articles)
    if logging:
        elapsed_seconds = (datetime.now() - current_time).seconds
        current_time = datetime.now()
        logger.info(f'user_last_impression_publish_time_diff/elapsed_seconds: {elapsed_seconds}/df shape: {df.shape}')
                    
    df = feat_article_pop(df,mode,df_pop_path='/home/data/article_pop_inview/',metacol=None)
    
    if logging:
        elapsed_seconds = (datetime.now() - current_time).seconds
        current_time = datetime.now()
        logger.info(f'article_pop/elapsed_seconds: {elapsed_seconds}/df shape: {df.shape}')

    df = add_past_category_ratios(df,df_history)
    if logging:
        elapsed_seconds = (datetime.now() - current_time).seconds
        current_time = datetime.now()
        logger.info(f'add_past_category_ratios/elapsed_seconds: {elapsed_seconds}/df shape: {df.shape}')
        
    df = add_next_impression_id_cossim(df, common_vec_dict["multilingual-e5-large-instruct"], method="mean")
    df = add_next_impression_id_cossim(df, common_vec_dict["multilingual-e5-large-instruct"], method="min")
    df = add_next_impression_id_cossim(df, common_vec_dict["multilingual-e5-large-instruct"], method="max")
    if logging:
        elapsed_seconds = (datetime.now() - current_time).seconds
        current_time = datetime.now()
        logger.info(f'add_next_impression_id_cossim/elapsed_seconds: {elapsed_seconds}/df shape: {df.shape}')

    for k,v in common_vec_dict.items():
        for type in ['mean','scroll_mean','read_time_mean']:#'min', 'max', 
            for window in [1,0]:
                if window == 1 and type != 'mean':
                    continue

                df = feat_clicked_cossim(df,df_history,v,f'click_cossim_{k}_{type}_{window}',type,window)
            
            if logging:
                logger.info(f'k: {k}, type: {type}')
                elapsed_seconds = (datetime.now() - current_time).seconds
                current_time = datetime.now()
                logger.info(f'clicked_inview_common_cossim/elapsed_seconds: {elapsed_seconds}/df shape: {df.shape}')
                
            df = feat_clicked_category_cossim(df,df_history,v,f'category_click_cossim_{k}_{type}',type,window=0)
            if logging:
                logger.info(f'k: {k}, type: {type}')
                elapsed_seconds = (datetime.now() - current_time).seconds
                current_time = datetime.now()
                logger.info(f'category_click_cossim/elapsed_seconds: {elapsed_seconds}/df shape: {df.shape}')

        df = feat_inview_cossim(df,v,f'inview_cossim_{k}')

        if logging:
            logger.info(f'k: {k}')
            elapsed_seconds = (datetime.now() - current_time).seconds
            current_time = datetime.now()
            logger.info(f'inview_my_cossim/elapsed_seconds: {elapsed_seconds}/df shape: {df.shape}')

        df = add_cossim_individual_features(df, df_history, v, f"{k}_individual")
        if logging:
            logger.info(f'k: {k}')
            elapsed_seconds = (datetime.now() - current_time).seconds
            current_time = datetime.now()
            logger.info(f'add_cossim_individual_features/elapsed_seconds: {elapsed_seconds}/df shape: {df.shape}')
    

    for k,v in my_vec_dict.items():
        for type in ['mean','scroll_mean','read_time_mean']:
            for window in [1,2,3,0]:
                if window == 1 and type != 'mean':
                    continue
                #clickベース
                df = feat_clicked_cossim(df,df_history,v[mode],f'click_cossim_{k}_{type}_{window}',type,window)

                if logging:
                    logger.info(f'k: {k}, type: {type}')
                    elapsed_seconds = (datetime.now() - current_time).seconds
                    current_time = datetime.now()
                    logger.info(f'clicked_inview_my_cossim/elapsed_seconds: {elapsed_seconds}/df shape: {df.shape}')

    cat_cols = ["device_type", "is_subscriber", "is_sso_user"]
    for k,v in common_vec_dict.items():
        if k == 'one_hot':
            continue
        for cat_col in cat_cols:
            df = add_cossim_by_category(
                df,
                df_history.rename(
                    {"impression_time_fixed": "impression_time",
                     "scroll_percentage_fixed": "scroll_percentage",
                     "article_id_fixed": "article_id",
                     "read_time_fixed": "read_time"}
                ).explode(
                    ["impression_time", "scroll_percentage", "article_id", "read_time"]
                ).sort(
                    ["user_id", "impression_time"]
                ),
                v,
                f"cossim__{k}__{cat_col}", cat_col)
        
            if logging:
                logger.info(f'k: {k}, cat_col: {cat_col}')
                elapsed_seconds = (datetime.now() - current_time).seconds
                current_time = datetime.now()
                logger.info(f'add_cossim_by_category/elapsed_seconds: {elapsed_seconds}/df shape: {df.shape}')
        
    df = calculate_inview_counts(df)
    if logging:
        elapsed_seconds = (datetime.now() - current_time).seconds
        current_time = datetime.now()
        logger.info(f'calculate_inview_counts/elapsed_seconds: {elapsed_seconds}/df shape: {df.shape}')

    for col in df.columns:
        if df[col].dtype == pl.Boolean:
            df = df.with_columns(pl.col(col).cast(pl.Int32))
            
    df = add_statistic(df)
    if logging:
        elapsed_seconds = (datetime.now() - current_time).seconds
        current_time = datetime.now()
        logger.info(f'statistic/elapsed_seconds: {elapsed_seconds}/df shape: {df.shape}')
    
    df = df.with_columns([
        (pl.col('total_pageviews') / pl.col('total_inviews')).alias('pageviews/inviews'),
        (pl.col('total_read_time') / pl.col('total_inviews')).alias('read_time/inviews'),
        pl.col('published_time_diff').rank().over('impression_id').alias('published_time_diff_rank'),
    ])

    rank_cols = ['total_inviews_norm', 'total_pageviews_norm', 'total_read_time_norm', 'rounded_1m_inview_count', 'rounded_2m_inview_count',
                 'rounded_3m_inview_count','rounded_5m_inview_count','rounded_10m_inview_count','rounded_15m_inview_count','rounded_20m_inview_count',
                 'rounded_30m_inview_count','rounded_1h_inview_count','rounded_3h_inview_count','rounded_6h_inview_count','rounded_12h_inview_count','rounded_24h_inview_count',
                 'inview_count', 'past_inview_count', 'time_gap_to_next_inview_impression_time', 'time_gap_from_prev_inview_impression_time', 
                 'next_impression_id_mean_cossim', 'next_impression_id_min_cossim', 'next_impression_id_max_cossim', 
                 'published_time_diff','published_time_diff_min-published_time_diff'
                ]
    for col in rank_cols:
        df = df.with_columns(pl.col(col).rank(descending =True).over('impression_id').alias(f'{col}_rank'))

    df = df.with_columns([
        df['impression_time'].dt.hour().alias('hour'),
        df['impression_time'].dt.minute().alias('minute'),
        df['impression_time'].dt.second().alias('second'),
        df['impression_time'].dt.weekday().alias('weekday')
    ])    
    
    df = normalize_rank_by_percentage(df)
    
    grouped_df = df.groupby("article_id").agg(
        [
            pl.col("count_article_ids_inview").mean().alias("mean_count_article_ids_inview"),
            pl.col("count_article_ids_inview").min().alias("min_count_article_ids_inview"),
            pl.col("count_article_ids_inview").median().alias("median_count_article_ids_inview"),
        ]
    )
    df = df.join(grouped_df, on=["article_id"], how="left")
    
    df = add_published_time_features(df, df_history)

    return df

# %% [markdown]
# # Train

# %%
n_chunks = 100

trn_df = get_target_df(trn_behaviors)
unique_user_ids = trn_df["user_id"].unique().to_numpy()

np.random.shuffle(unique_user_ids)
user_id_splits = np.array_split(unique_user_ids, n_chunks)

for _chunk in range(n_chunks):
    
    logger.info(f"Starting Chunk {_chunk}")

    df_chunk = trn_df.filter(pl.col("user_id").is_in(set(user_id_splits[_chunk])))
    df_history_chunk = trn_history.filter(pl.col("user_id").is_in(set(user_id_splits[_chunk])))
    df_chunk = create_feature(df_chunk,df_history_chunk,mode='train')
    
    df_chunk.write_parquet(f"./trn_large_chunks/trn_df_chunk{_chunk}.parquet")
    
    del df_chunk
    import gc; gc.collect()
# Out:
# [2024-06-17 00:33:55,133][INFO] Starting Chunk 0
# [2024-06-17 00:33:56,755][INFO] start:feature_engineering
# [2024-06-17 00:33:56,756][INFO] df shape: (1363705, 15)
# [2024-06-17 00:33:58,185][INFO] clicked_history_count/elapsed_seconds: 1/df shape: (1363705, 18)
# [2024-06-17 00:34:00,327][INFO] inview_cooccur/elapsed_seconds: 2/df shape: (1363705, 28)
# [2024-06-17 00:34:00,559][INFO] feat_article_simple/elapsed_seconds: 0/df shape: (1363705, 43)
# [2024-06-17 00:34:00,673][INFO] user_last_impression_publish_time_diff/elapsed_seconds: 0/df shape: (1363705, 44)
# [2024-06-17 00:34:04,482][INFO] article_pop/elapsed_seconds: 3/df shape: (1363705, 72)
# [2024-06-17 00:34:09,005][INFO] add_past_category_ratios/elapsed_seconds: 4/df shape: (1363705, 75)
# [2024-06-17 00:34:23,663][INFO] add_next_impression_id_cossim/elapsed_seconds: 14/df shape: (1363705, 78)
# [2024-06-17 00:34:36,420][INFO] k: multilingual-e5-large-instruct, type: mean
# [2024-06-17 00:34:36,425][INFO] clicked_inview_common_cossim/elapsed_seconds: 12/df shape: (1363705, 80)
# [2024-06-17 00:34:43,483][INFO] k: multilingual-e5-large-instruct, type: mean
# [2024-06-17 00:34:43,484][INFO] category_click_cossim/elapsed_seconds: 7/df shape: (1363705, 81)
# [2024-06-17 00:34:53,962][INFO] k: multilingual-e5-large-instruct, type: scroll_mean
# [2024-06-17 00:34:53,963][INFO] clicked_inview_common_cossim/elapsed_seconds: 10/df shape: (1363705, 82)
# [2024-06-17 00:35:05,354][INFO] k: multilingual-e5-large-instruct, type: scroll_mean
# [2024-06-17 00:35:05,355][INFO] category_click_cossim/elapsed_seconds: 11/df shape: (1363705, 83)
# [2024-06-17 00:35:15,331][INFO] k: multilingual-e5-large-instruct, type: read_time_mean
# [2024-06-17 00:35:15,332][INFO] clicked_inview_common_cossim/elapsed_seconds: 9/df shape: (1363705, 84)
# [2024-06-17 00:35:26,311][INFO] k: multilingual-e5-large-instruct, type: read_time_mean
# [2024-06-17 00:35:26,314][INFO] category_click_cossim/elapsed_seconds: 10/df shape: (1363705, 85)
# [2024-06-17 00:35:45,723][INFO] k: multilingual-e5-large-instruct
# [2024-06-17 00:35:45,724][INFO] inview_my_cossim/elapsed_seconds: 19/df shape: (1363705, 88)
# [2024-06-17 00:36:39,851][INFO] k: multilingual-e5-large-instruct
# [2024-06-17 00:36:39,854][INFO] add_cossim_individual_features/elapsed_seconds: 54/df shape: (1363705, 96)
# [2024-06-17 00:36:41,329][INFO] k: item2vec, type: mean
# [2024-06-17 00:36:41,331][INFO] clicked_inview_my_cossim/elapsed_seconds: 1/df shape: (1363705, 97)
# [2024-06-17 00:36:42,666][INFO] k: item2vec, type: mean
# [2024-06-17 00:36:42,667][INFO] clicked_inview_my_cossim/elapsed_seconds: 1/df shape: (1363705, 98)
# [2024-06-17 00:36:43,976][INFO] k: item2vec, type: mean
# [2024-06-17 00:36:43,977][INFO] clicked_inview_my_cossim/elapsed_seconds: 1/df shape: (1363705, 99)
# [2024-06-17 00:36:45,241][INFO] k: item2vec, type: mean
# [2024-06-17 00:36:45,242][INFO] clicked_inview_my_cossim/elapsed_seconds: 1/df shape: (1363705, 100)
# [2024-06-17 00:36:46,586][INFO] k: item2vec, type: scroll_mean
# [2024-06-17 00:36:46,587][INFO] clicked_inview_my_cossim/elapsed_seconds: 1/df shape: (1363705, 101)
# [2024-06-17 00:36:47,898][INFO] k: item2vec, type: scroll_mean
# [2024-06-17 00:36:47,899][INFO] clicked_inview_my_cossim/elapsed_seconds: 1/df shape: (1363705, 102)
# [2024-06-17 00:36:49,413][INFO] k: item2vec, type: scroll_mean
# [2024-06-17 00:36:49,414][INFO] clicked_inview_my_cossim/elapsed_seconds: 1/df shape: (1363705, 103)
# [2024-06-17 00:36:50,758][INFO] k: item2vec, type: read_time_mean
# [2024-06-17 00:36:50,759][INFO] clicked_inview_my_cossim/elapsed_seconds: 1/df shape: (1363705, 104)
# [2024-06-17 00:36:52,110][INFO] k: item2vec, type: read_time_mean
# [2024-06-17 00:36:52,111][INFO] clicked_inview_my_cossim/elapsed_seconds: 1/df shape: (1363705, 105)
# [2024-06-17 00:36:53,622][INFO] k: item2vec, type: read_time_mean
# [2024-06-17 00:36:53,623][INFO] clicked_inview_my_cossim/elapsed_seconds: 1/df shape: (1363705, 106)
# [2024-06-17 00:37:11,464][INFO] k: multilingual-e5-large-instruct, cat_col: device_type
# [2024-06-17 00:37:11,465][INFO] add_cossim_by_category/elapsed_seconds: 17/df shape: (1363705, 107)
# [2024-06-17 00:37:27,331][INFO] k: multilingual-e5-large-instruct, cat_col: is_subscriber
# [2024-06-17 00:37:27,333][INFO] add_cossim_by_category/elapsed_seconds: 15/df shape: (1363705, 108)
# [2024-06-17 00:37:43,420][INFO] k: multilingual-e5-large-instruct, cat_col: is_sso_user
# [2024-06-17 00:37:43,421][INFO] add_cossim_by_category/elapsed_seconds: 16/df shape: (1363705, 109)
# [2024-06-17 00:37:47,567][INFO] calculate_inview_counts/elapsed_seconds: 4/df shape: (1363705, 113)
# [2024-06-17 00:37:51,794][INFO] statistic/elapsed_seconds: 4/df shape: (1363705, 404)
# [2024-06-17 00:38:25,095][INFO] Starting Chunk 1
# [2024-06-17 00:38:26,748][INFO] start:feature_engineering
# [2024-06-17 00:38:26,749][INFO] df shape: (1356521, 15)
# [2024-06-17 00:38:28,196][INFO] clicked_history_count/elapsed_seconds: 1/df shape: (1356521, 18)
# [2024-06-17 00:38:30,485][INFO] inview_cooccur/elapsed_seconds: 2/df shape: (1356521, 28)
# [2024-06-17 00:38:30,714][INFO] feat_article_simple/elapsed_seconds: 0/df shape: (1356521, 43)
# [2024-06-17 00:38:30,826][INFO] user_last_impression_publish_time_diff/elapsed_seconds: 0/df shape: (1356521, 44)
# [2024-06-17 00:38:34,718][INFO] article_pop/elapsed_seconds: 3/df shape: (1356521, 72)
# [2024-06-17 00:38:39,052][INFO] add_past_category_ratios/elapsed_seconds: 4/df shape: (1356521, 75)
# [2024-06-17 00:38:53,613][INFO] add_next_impression_id_cossim/elapsed_seconds: 14/df shape: (1356521, 78)
# [2024-06-17 00:39:06,641][INFO] k: multilingual-e5-large-instruct, type: mean
# [2024-06-17 00:39:06,642][INFO] clicked_inview_common_cossim/elapsed_seconds: 13/df shape: (1356521, 80)
# [2024-06-17 00:39:13,777][INFO] k: multilingual-e5-large-instruct, type: mean
# [2024-06-17 00:39:13,778][INFO] category_click_cossim/elapsed_seconds: 7/df shape: (1356521, 81)
# [2024-06-17 00:39:24,329][INFO] k: multilingual-e5-large-instruct, type: scroll_mean
# [2024-06-17 00:39:24,330][INFO] clicked_inview_common_cossim/elapsed_seconds: 10/df shape: (1356521, 82)
# [2024-06-17 00:39:35,906][INFO] k: multilingual-e5-large-instruct, type: scroll_mean
# [2024-06-17 00:39:35,907][INFO] category_click_cossim/elapsed_seconds: 11/df shape: (1356521, 83)
# [2024-06-17 00:39:46,067][INFO] k: multilingual-e5-large-instruct, type: read_time_mean
# [2024-06-17 00:39:46,068][INFO] clicked_inview_common_cossim/elapsed_seconds: 10/df shape: (1356521, 84)
# [2024-06-17 00:39:57,064][INFO] k: multilingual-e5-large-instruct, type: read_time_mean
# [2024-06-17 00:39:57,066][INFO] category_click_cossim/elapsed_seconds: 10/df shape: (1356521, 85)
# [2024-06-17 00:40:16,510][INFO] k: multilingual-e5-large-instruct
# [2024-06-17 00:40:16,511][INFO] inview_my_cossim/elapsed_seconds: 19/df shape: (1356521, 88)
# [2024-06-17 00:41:11,083][INFO] k: multilingual-e5-large-instruct
# [2024-06-17 00:41:11,085][INFO] add_cossim_individual_features/elapsed_seconds: 54/df shape: (1356521, 96)
# [2024-06-17 00:41:12,540][INFO] k: item2vec, type: mean
# [2024-06-17 00:41:12,541][INFO] clicked_inview_my_cossim/elapsed_seconds: 1/df shape: (1356521, 97)
# [2024-06-17 00:41:13,826][INFO] k: item2vec, type: mean
# [2024-06-17 00:41:13,827][INFO] clicked_inview_my_cossim/elapsed_seconds: 1/df shape: (1356521, 98)
# [2024-06-17 00:41:15,108][INFO] k: item2vec, type: mean
# [2024-06-17 00:41:15,109][INFO] clicked_inview_my_cossim/elapsed_seconds: 1/df shape: (1356521, 99)
# [2024-06-17 00:41:16,423][INFO] k: item2vec, type: mean
# [2024-06-17 00:41:16,425][INFO] clicked_inview_my_cossim/elapsed_seconds: 1/df shape: (1356521, 100)
# [2024-06-17 00:41:17,735][INFO] k: item2vec, type: scroll_mean
# [2024-06-17 00:41:17,736][INFO] clicked_inview_my_cossim/elapsed_seconds: 1/df shape: (1356521, 101)
# [2024-06-17 00:41:19,053][INFO] k: item2vec, type: scroll_mean
# [2024-06-17 00:41:19,055][INFO] clicked_inview_my_cossim/elapsed_seconds: 1/df shape: (1356521, 102)
# [2024-06-17 00:41:20,569][INFO] k: item2vec, type: scroll_mean
# [2024-06-17 00:41:20,570][INFO] clicked_inview_my_cossim/elapsed_seconds: 1/df shape: (1356521, 103)
# [2024-06-17 00:41:21,901][INFO] k: item2vec, type: read_time_mean
# [2024-06-17 00:41:21,903][INFO] clicked_inview_my_cossim/elapsed_seconds: 1/df shape: (1356521, 104)
# [2024-06-17 00:41:23,237][INFO] k: item2vec, type: read_time_mean
# [2024-06-17 00:41:23,238][INFO] clicked_inview_my_cossim/elapsed_seconds: 1/df shape: (1356521, 105)
# [2024-06-17 00:41:24,704][INFO] k: item2vec, type: read_time_mean
# [2024-06-17 00:41:24,705][INFO] clicked_inview_my_cossim/elapsed_seconds: 1/df shape: (1356521, 106)
# [2024-06-17 00:41:42,366][INFO] k: multilingual-e5-large-instruct, cat_col: device_type
# [2024-06-17 00:41:42,367][INFO] add_cossim_by_category/elapsed_seconds: 17/df shape: (1356521, 107)
# [2024-06-17 00:41:58,243][INFO] k: multilingual-e5-large-instruct, cat_col: is_subscriber
# [2024-06-17 00:41:58,245][INFO] add_cossim_by_category/elapsed_seconds: 15/df shape: (1356521, 108)
# [2024-06-17 00:42:14,324][INFO] k: multilingual-e5-large-instruct, cat_col: is_sso_user
# [2024-06-17 00:42:14,325][INFO] add_cossim_by_category/elapsed_seconds: 16/df shape: (1356521, 109)
# [2024-06-17 00:42:18,438][INFO] calculate_inview_counts/elapsed_seconds: 4/df shape: (1356521, 113)
# [2024-06-17 00:42:22,603][INFO] statistic/elapsed_seconds: 4/df shape: (1356521, 404)
# [2024-06-17 00:42:53,751][INFO] Starting Chunk 2
# [2024-06-17 00:42:55,371][INFO] start:feature_engineering
# [2024-06-17 00:42:55,372][INFO] df shape: (1313256, 15)
# [2024-06-17 00:42:56,771][INFO] clicked_history_count/elapsed_seconds: 1/df shape: (1313256, 18)
# [2024-06-17 00:42:58,978][INFO] inview_cooccur/elapsed_seconds: 2/df shape: (1313256, 28)
# [2024-06-17 00:42:59,207][INFO] feat_article_simple/elapsed_seconds: 0/df shape: (1313256, 43)
# [2024-06-17 00:42:59,317][INFO] user_last_impression_publish_time_diff/elapsed_seconds: 0/df shape: (1313256, 44)
# [2024-06-17 00:43:03,092][INFO] article_pop/elapsed_seconds: 3/df shape: (1313256, 72)
# [2024-06-17 00:43:07,843][INFO] add_past_category_ratios/elapsed_seconds: 4/df shape: (1313256, 75)
# [2024-06-17 00:43:22,013][INFO] add_next_impression_id_cossim/elapsed_seconds: 14/df shape: (1313256, 78)
# [2024-06-17 00:43:34,817][INFO] k: multilingual-e5-large-instruct, type: mean
# [2024-06-17 00:43:34,818][INFO] clicked_inview_common_cossim/elapsed_seconds: 12/df shape: (1313256, 80)
# [2024-06-17 00:43:41,778][INFO] k: multilingual-e5-large-instruct, type: mean
# [2024-06-17 00:43:41,780][INFO] category_click_cossim/elapsed_seconds: 6/df shape: (1313256, 81)
# [2024-06-17 00:43:52,323][INFO] k: multilingual-e5-large-instruct, type: scroll_mean
# [2024-06-17 00:43:52,324][INFO] clicked_inview_common_cossim/elapsed_seconds: 10/df shape: (1313256, 82)
# [2024-06-17 00:44:03,757][INFO] k: multilingual-e5-large-instruct, type: scroll_mean
# [2024-06-17 00:44:03,758][INFO] category_click_cossim/elapsed_seconds: 11/df shape: (1313256, 83)
# [2024-06-17 00:44:13,606][INFO] k: multilingual-e5-large-instruct, type: read_time_mean
# [2024-06-17 00:44:13,608][INFO] clicked_inview_common_cossim/elapsed_seconds: 9/df shape: (1313256, 84)
# [2024-06-17 00:44:24,326][INFO] k: multilingual-e5-large-instruct, type: read_time_mean
# [2024-06-17 00:44:24,327][INFO] category_click_cossim/elapsed_seconds: 10/df shape: (1313256, 85)
# [2024-06-17 00:44:43,301][INFO] k: multilingual-e5-large-instruct
# [2024-06-17 00:44:43,302][INFO] inview_my_cossim/elapsed_seconds: 18/df shape: (1313256, 88)
# [2024-06-17 00:45:37,084][INFO] k: multilingual-e5-large-instruct
# [2024-06-17 00:45:37,087][INFO] add_cossim_individual_features/elapsed_seconds: 53/df shape: (1313256, 96)
# [2024-06-17 00:45:38,571][INFO] k: item2vec, type: mean
# [2024-06-17 00:45:38,572][INFO] clicked_inview_my_cossim/elapsed_seconds: 1/df shape: (1313256, 97)
# [2024-06-17 00:45:39,882][INFO] k: item2vec, type: mean
# [2024-06-17 00:45:39,883][INFO] clicked_inview_my_cossim/elapsed_seconds: 1/df shape: (1313256, 98)
# [2024-06-17 00:45:41,175][INFO] k: item2vec, type: mean
# [2024-06-17 00:45:41,176][INFO] clicked_inview_my_cossim/elapsed_seconds: 1/df shape: (1313256, 99)
# [2024-06-17 00:45:42,433][INFO] k: item2vec, type: mean
# [2024-06-17 00:45:42,434][INFO] clicked_inview_my_cossim/elapsed_seconds: 1/df shape: (1313256, 100)
# [2024-06-17 00:45:43,741][INFO] k: item2vec, type: scroll_mean
# [2024-06-17 00:45:43,742][INFO] clicked_inview_my_cossim/elapsed_seconds: 1/df shape: (1313256, 101)
# [2024-06-17 00:45:45,025][INFO] k: item2vec, type: scroll_mean
# [2024-06-17 00:45:45,026][INFO] clicked_inview_my_cossim/elapsed_seconds: 1/df shape: (1313256, 102)
# [2024-06-17 00:45:46,568][INFO] k: item2vec, type: scroll_mean
# [2024-06-17 00:45:46,569][INFO] clicked_inview_my_cossim/elapsed_seconds: 1/df shape: (1313256, 103)
# [2024-06-17 00:45:47,845][INFO] k: item2vec, type: read_time_mean
# [2024-06-17 00:45:47,846][INFO] clicked_inview_my_cossim/elapsed_seconds: 1/df shape: (1313256, 104)
# [2024-06-17 00:45:49,185][INFO] k: item2vec, type: read_time_mean
# [2024-06-17 00:45:49,186][INFO] clicked_inview_my_cossim/elapsed_seconds: 1/df shape: (1313256, 105)
# [2024-06-17 00:45:50,674][INFO] k: item2vec, type: read_time_mean
# [2024-06-17 00:45:50,675][INFO] clicked_inview_my_cossim/elapsed_seconds: 1/df shape: (1313256, 106)
# [2024-06-17 00:46:07,675][INFO] k: multilingual-e5-large-instruct, cat_col: device_type
# [2024-06-17 00:46:07,676][INFO] add_cossim_by_category/elapsed_seconds: 17/df shape: (1313256, 107)
# [2024-06-17 00:46:23,257][INFO] k: multilingual-e5-large-instruct, cat_col: is_subscriber
# [2024-06-17 00:46:23,258][INFO] add_cossim_by_category/elapsed_seconds: 15/df shape: (1313256, 108)
# [2024-06-17 00:46:38,840][INFO] k: multilingual-e5-large-instruct, cat_col: is_sso_user
# [2024-06-17 00:46:38,841][INFO] add_cossim_by_category/elapsed_seconds: 15/df shape: (1313256, 109)
# [2024-06-17 00:46:42,906][INFO] calculate_inview_counts/elapsed_seconds: 4/df shape: (1313256, 113)
# [2024-06-17 00:46:46,967][INFO] statistic/elapsed_seconds: 4/df shape: (1313256, 404)
# [2024-06-17 00:47:17,536][INFO] Starting Chunk 3
# [2024-06-17 00:47:19,138][INFO] start:feature_engineering
# [2024-06-17 00:47:19,139][INFO] df shape: (1323710, 15)
# [2024-06-17 00:47:20,540][INFO] clicked_history_count/elapsed_seconds: 1/df shape: (1323710, 18)
# [2024-06-17 00:47:22,748][INFO] inview_cooccur/elapsed_seconds: 2/df shape: (1323710, 28)
# [2024-06-17 00:47:22,977][INFO] feat_article_simple/elapsed_seconds: 0/df shape: (1323710, 43)
# [2024-06-17 00:47:23,088][INFO] user_last_impression_publish_time_diff/elapsed_seconds: 0/df shape: (1323710, 44)
# [2024-06-17 00:47:27,029][INFO] article_pop/elapsed_seconds: 3/df shape: (1323710, 72)
# [2024-06-17 00:47:31,428][INFO] add_past_category_ratios/elapsed_seconds: 4/df shape: (1323710, 75)
# [2024-06-17 00:47:45,742][INFO] add_next_impression_id_cossim/elapsed_seconds: 14/df shape: (1323710, 78)
# [2024-06-17 00:47:58,544][INFO] k: multilingual-e5-large-instruct, type: mean
# [2024-06-17 00:47:58,545][INFO] clicked_inview_common_cossim/elapsed_seconds: 12/df shape: (1323710, 80)
# [2024-06-17 00:48:05,527][INFO] k: multilingual-e5-large-instruct, type: mean
# [2024-06-17 00:48:05,528][INFO] category_click_cossim/elapsed_seconds: 6/df shape: (1323710, 81)
# [2024-06-17 00:48:16,060][INFO] k: multilingual-e5-large-instruct, type: scroll_mean
# [2024-06-17 00:48:16,061][INFO] clicked_inview_common_cossim/elapsed_seconds: 10/df shape: (1323710, 82)
# [2024-06-17 00:48:27,486][INFO] k: multilingual-e5-large-instruct, type: scroll_mean
# [2024-06-17 00:48:27,487][INFO] category_click_cossim/elapsed_seconds: 11/df shape: (1323710, 83)
# [2024-06-17 00:48:37,279][INFO] k: multilingual-e5-large-instruct, type: read_time_mean
# [2024-06-17 00:48:37,281][INFO] clicked_inview_common_cossim/elapsed_seconds: 9/df shape: (1323710, 84)
# [2024-06-17 00:48:48,241][INFO] k: multilingual-e5-large-instruct, type: read_time_mean
# [2024-06-17 00:48:48,242][INFO] category_click_cossim/elapsed_seconds: 10/df shape: (1323710, 85)
# [2024-06-17 00:49:07,065][INFO] k: multilingual-e5-large-instruct
# [2024-06-17 00:49:07,066][INFO] inview_my_cossim/elapsed_seconds: 18/df shape: (1323710, 88)
# [2024-06-17 00:50:00,211][INFO] k: multilingual-e5-large-instruct
# [2024-06-17 00:50:00,213][INFO] add_cossim_individual_features/elapsed_seconds: 53/df shape: (1323710, 96)
# [2024-06-17 00:50:01,676][INFO] k: item2vec, type: mean
# [2024-06-17 00:50:01,677][INFO] clicked_inview_my_cossim/elapsed_seconds: 1/df shape: (1323710, 97)
# [2024-06-17 00:50:02,997][INFO] k: item2vec, type: mean
# [2024-06-17 00:50:02,998][INFO] clicked_inview_my_cossim/elapsed_seconds: 1/df shape: (1323710, 98)
# [2024-06-17 00:50:04,302][INFO] k: item2vec, type: mean
# [2024-06-17 00:50:04,303][INFO] clicked_inview_my_cossim/elapsed_seconds: 1/df shape: (1323710, 99)
# [2024-06-17 00:50:05,494][INFO] k: item2vec, type: mean
# [2024-06-17 00:50:05,495][INFO] clicked_inview_my_cossim/elapsed_seconds: 1/df shape: (1323710, 100)
# [2024-06-17 00:50:06,801][INFO] k: item2vec, type: scroll_mean
# [2024-06-17 00:50:06,802][INFO] clicked_inview_my_cossim/elapsed_seconds: 1/df shape: (1323710, 101)
# [2024-06-17 00:50:08,081][INFO] k: item2vec, type: scroll_mean
# [2024-06-17 00:50:08,082][INFO] clicked_inview_my_cossim/elapsed_seconds: 1/df shape: (1323710, 102)
# [2024-06-17 00:50:09,624][INFO] k: item2vec, type: scroll_mean
# [2024-06-17 00:50:09,625][INFO] clicked_inview_my_cossim/elapsed_seconds: 1/df shape: (1323710, 103)
# [2024-06-17 00:50:10,956][INFO] k: item2vec, type: read_time_mean
# [2024-06-17 00:50:10,957][INFO] clicked_inview_my_cossim/elapsed_seconds: 1/df shape: (1323710, 104)
# [2024-06-17 00:50:12,272][INFO] k: item2vec, type: read_time_mean
# [2024-06-17 00:50:12,273][INFO] clicked_inview_my_cossim/elapsed_seconds: 1/df shape: (1323710, 105)
# [2024-06-17 00:50:13,740][INFO] k: item2vec, type: read_time_mean
# [2024-06-17 00:50:13,741][INFO] clicked_inview_my_cossim/elapsed_seconds: 1/df shape: (1323710, 106)
# [2024-06-17 00:50:30,894][INFO] k: multilingual-e5-large-instruct, cat_col: device_type
# [2024-06-17 00:50:30,895][INFO] add_cossim_by_category/elapsed_seconds: 17/df shape: (1323710, 107)
# [2024-06-17 00:50:46,431][INFO] k: multilingual-e5-large-instruct, cat_col: is_subscriber
# [2024-06-17 00:50:46,432][INFO] add_cossim_by_category/elapsed_seconds: 15/df shape: (1323710, 108)
# [2024-06-17 00:51:02,104][INFO] k: multilingual-e5-large-instruct, cat_col: is_sso_user
# [2024-06-17 00:51:02,105][INFO] add_cossim_by_category/elapsed_seconds: 15/df shape: (1323710, 109)
# [2024-06-17 00:51:06,168][INFO] calculate_inview_counts/elapsed_seconds: 4/df shape: (1323710, 113)
# [2024-06-17 00:51:10,197][INFO] statistic/elapsed_seconds: 4/df shape: (1323710, 404)
# [2024-06-17 00:51:41,224][INFO] Starting Chunk 4
# [2024-06-17 00:51:42,850][INFO] start:feature_engineering
# [2024-06-17 00:51:42,851][INFO] df shape: (1352793, 15)
# [2024-06-17 00:51:44,246][INFO] clicked_history_count/elapsed_seconds: 1/df shape: (1352793, 18)
# [2024-06-17 00:51:46,478][INFO] inview_cooccur/elapsed_seconds: 2/df shape: (1352793, 28)
# [2024-06-17 00:51:46,702][INFO] feat_article_simple/elapsed_seconds: 0/df shape: (1352793, 43)
# [2024-06-17 00:51:46,813][INFO] user_last_impression_publish_time_diff/elapsed_seconds: 0/df shape: (1352793, 44)
# [2024-06-17 00:51:50,611][INFO] article_pop/elapsed_seconds: 3/df shape: (1352793, 72)
# [2024-06-17 00:51:55,139][INFO] add_past_category_ratios/elapsed_seconds: 4/df shape: (1352793, 75)
# [2024-06-17 00:52:09,556][INFO] add_next_impression_id_cossim/elapsed_seconds: 14/df shape: (1352793, 78)
# [2024-06-17 00:52:22,341][INFO] k: multilingual-e5-large-instruct, type: mean
# [2024-06-17 00:52:22,343][INFO] clicked_inview_common_cossim/elapsed_seconds: 12/df shape: (1352793, 80)
# [2024-06-17 00:52:29,379][INFO] k: multilingual-e5-large-instruct, type: mean
# [2024-06-17 00:52:29,381][INFO] category_click_cossim/elapsed_seconds: 7/df shape: (1352793, 81)
# [2024-06-17 00:52:39,830][INFO] k: multilingual-e5-large-instruct, type: scroll_mean
# [2024-06-17 00:52:39,831][INFO] clicked_inview_common_cossim/elapsed_seconds: 10/df shape: (1352793, 82)
# [2024-06-17 00:52:51,361][INFO] k: multilingual-e5-large-instruct, type: scroll_mean
# [2024-06-17 00:52:51,362][INFO] category_click_cossim/elapsed_seconds: 11/df shape: (1352793, 83)
# [2024-06-17 00:53:01,407][INFO] k: multilingual-e5-large-instruct, type: read_time_mean
# [2024-06-17 00:53:01,408][INFO] clicked_inview_common_cossim/elapsed_seconds: 10/df shape: (1352793, 84)
# [2024-06-17 00:53:12,338][INFO] k: multilingual-e5-large-instruct, type: read_time_mean
# [2024-06-17 00:53:12,340][INFO] category_click_cossim/elapsed_seconds: 10/df shape: (1352793, 85)
# [2024-06-17 00:53:31,680][INFO] k: multilingual-e5-large-instruct
# [2024-06-17 00:53:31,682][INFO] inview_my_cossim/elapsed_seconds: 19/df shape: (1352793, 88)
# [2024-06-17 00:54:25,105][INFO] k: multilingual-e5-large-instruct
# [2024-06-17 00:54:25,108][INFO] add_cossim_individual_features/elapsed_seconds: 53/df shape: (1352793, 96)
# [2024-06-17 00:54:26,594][INFO] k: item2vec, type: mean
# [2024-06-17 00:54:26,595][INFO] clicked_inview_my_cossim/elapsed_seconds: 1/df shape: (1352793, 97)
# [2024-06-17 00:54:27,863][INFO] k: item2vec, type: mean
# [2024-06-17 00:54:27,864][INFO] clicked_inview_my_cossim/elapsed_seconds: 1/df shape: (1352793, 98)
# [2024-06-17 00:54:29,147][INFO] k: item2vec, type: mean
# [2024-06-17 00:54:29,148][INFO] clicked_inview_my_cossim/elapsed_seconds: 1/df shape: (1352793, 99)
# [2024-06-17 00:54:30,417][INFO] k: item2vec, type: mean
# [2024-06-17 00:54:30,418][INFO] clicked_inview_my_cossim/elapsed_seconds: 1/df shape: (1352793, 100)
# [2024-06-17 00:54:31,728][INFO] k: item2vec, type: scroll_mean
# [2024-06-17 00:54:31,729][INFO] clicked_inview_my_cossim/elapsed_seconds: 1/df shape: (1352793, 101)
# [2024-06-17 00:54:33,089][INFO] k: item2vec, type: scroll_mean
# [2024-06-17 00:54:33,090][INFO] clicked_inview_my_cossim/elapsed_seconds: 1/df shape: (1352793, 102)
# [2024-06-17 00:54:34,570][INFO] k: item2vec, type: scroll_mean
# [2024-06-17 00:54:34,571][INFO] clicked_inview_my_cossim/elapsed_seconds: 1/df shape: (1352793, 103)
# [2024-06-17 00:54:35,869][INFO] k: item2vec, type: read_time_mean
# [2024-06-17 00:54:35,871][INFO] clicked_inview_my_cossim/elapsed_seconds: 1/df shape: (1352793, 104)
# [2024-06-17 00:54:37,109][INFO] k: item2vec, type: read_time_mean
# [2024-06-17 00:54:37,110][INFO] clicked_inview_my_cossim/elapsed_seconds: 1/df shape: (1352793, 105)
# [2024-06-17 00:54:38,599][INFO] k: item2vec, type: read_time_mean
# [2024-06-17 00:54:38,601][INFO] clicked_inview_my_cossim/elapsed_seconds: 1/df shape: (1352793, 106)
# [2024-06-17 00:54:56,174][INFO] k: multilingual-e5-large-instruct, cat_col: device_type
# [2024-06-17 00:54:56,175][INFO] add_cossim_by_category/elapsed_seconds: 17/df shape: (1352793, 107)
# [2024-06-17 00:55:11,935][INFO] k: multilingual-e5-large-instruct, cat_col: is_subscriber
# [2024-06-17 00:55:11,936][INFO] add_cossim_by_category/elapsed_seconds: 15/df shape: (1352793, 108)
# [2024-06-17 00:55:27,659][INFO] k: multilingual-e5-large-instruct, cat_col: is_sso_user
# [2024-06-17 00:55:27,660][INFO] add_cossim_by_category/elapsed_seconds: 15/df shape: (1352793, 109)
# [2024-06-17 00:55:31,772][INFO] calculate_inview_counts/elapsed_seconds: 4/df shape: (1352793, 113)
# [2024-06-17 00:55:35,902][INFO] statistic/elapsed_seconds: 4/df shape: (1352793, 404)
# [2024-06-17 00:56:07,923][INFO] Starting Chunk 5
# [2024-06-17 00:56:09,541][INFO] start:feature_engineering
# [2024-06-17 00:56:09,542][INFO] df shape: (1356663, 15)
# [2024-06-17 00:56:10,963][INFO] clicked_history_count/elapsed_seconds: 1/df shape: (1356663, 18)
# [2024-06-17 00:56:13,185][INFO] inview_cooccur/elapsed_seconds: 2/df shape: (1356663, 28)
# [2024-06-17 00:56:13,439][INFO] feat_article_simple/elapsed_seconds: 0/df shape: (1356663, 43)
# [2024-06-17 00:56:13,556][INFO] user_last_impression_publish_time_diff/elapsed_seconds: 0/df shape: (1356663, 44)
# [2024-06-17 00:56:17,385][INFO] article_pop/elapsed_seconds: 3/df shape: (1356663, 72)
# [2024-06-17 00:56:22,227][INFO] add_past_category_ratios/elapsed_seconds: 4/df shape: (1356663, 75)
# [2024-06-17 00:56:36,885][INFO] add_next_impression_id_cossim/elapsed_seconds: 14/df shape: (1356663, 78)
# [2024-06-17 00:56:49,741][INFO] k: multilingual-e5-large-instruct, type: mean
# [2024-06-17 00:56:49,742][INFO] clicked_inview_common_cossim/elapsed_seconds: 12/df shape: (1356663, 80)
# [2024-06-17 00:56:56,835][INFO] k: multilingual-e5-large-instruct, type: mean
# [2024-06-17 00:56:56,837][INFO] category_click_cossim/elapsed_seconds: 7/df shape: (1356663, 81)
# [2024-06-17 00:57:07,263][INFO] k: multilingual-e5-large-instruct, type: scroll_mean
# [2024-06-17 00:57:07,264][INFO] clicked_inview_common_cossim/elapsed_seconds: 10/df shape: (1356663, 82)
# [2024-06-17 00:57:18,698][INFO] k: multilingual-e5-large-instruct, type: scroll_mean
# [2024-06-17 00:57:18,700][INFO] category_click_cossim/elapsed_seconds: 11/df shape: (1356663, 83)
# [2024-06-17 00:57:28,680][INFO] k: multilingual-e5-large-instruct, type: read_time_mean
# [2024-06-17 00:57:28,681][INFO] clicked_inview_common_cossim/elapsed_seconds: 9/df shape: (1356663, 84)
# [2024-06-17 00:57:39,592][INFO] k: multilingual-e5-large-instruct, type: read_time_mean
# [2024-06-17 00:57:39,593][INFO] category_click_cossim/elapsed_seconds: 10/df shape: (1356663, 85)
# [2024-06-17 00:57:59,043][INFO] k: multilingual-e5-large-instruct
# [2024-06-17 00:57:59,044][INFO] inview_my_cossim/elapsed_seconds: 19/df shape: (1356663, 88)
# [2024-06-17 00:58:53,251][INFO] k: multilingual-e5-large-instruct
# [2024-06-17 00:58:53,252][INFO] add_cossim_individual_features/elapsed_seconds: 54/df shape: (1356663, 96)
# [2024-06-17 00:58:54,698][INFO] k: item2vec, type: mean
# [2024-06-17 00:58:54,699][INFO] clicked_inview_my_cossim/elapsed_seconds: 1/df shape: (1356663, 97)
# [2024-06-17 00:58:56,051][INFO] k: item2vec, type: mean
# [2024-06-17 00:58:56,052][INFO] clicked_inview_my_cossim/elapsed_seconds: 1/df shape: (1356663, 98)
# [2024-06-17 00:58:57,371][INFO] k: item2vec, type: mean
# [2024-06-17 00:58:57,372][INFO] clicked_inview_my_cossim/elapsed_seconds: 1/df shape: (1356663, 99)
# [2024-06-17 00:58:58,636][INFO] k: item2vec, type: mean
# [2024-06-17 00:58:58,637][INFO] clicked_inview_my_cossim/elapsed_seconds: 1/df shape: (1356663, 100)
# [2024-06-17 00:58:59,968][INFO] k: item2vec, type: scroll_mean
# [2024-06-17 00:58:59,970][INFO] clicked_inview_my_cossim/elapsed_seconds: 1/df shape: (1356663, 101)
# [2024-06-17 00:59:01,297][INFO] k: item2vec, type: scroll_mean
# [2024-06-17 00:59:01,298][INFO] clicked_inview_my_cossim/elapsed_seconds: 1/df shape: (1356663, 102)
# [2024-06-17 00:59:02,844][INFO] k: item2vec, type: scroll_mean
# [2024-06-17 00:59:02,845][INFO] clicked_inview_my_cossim/elapsed_seconds: 1/df shape: (1356663, 103)
# [2024-06-17 00:59:04,183][INFO] k: item2vec, type: read_time_mean
# [2024-06-17 00:59:04,184][INFO] clicked_inview_my_cossim/elapsed_seconds: 1/df shape: (1356663, 104)
# [2024-06-17 00:59:05,531][INFO] k: item2vec, type: read_time_mean
# [2024-06-17 00:59:05,532][INFO] clicked_inview_my_cossim/elapsed_seconds: 1/df shape: (1356663, 105)
# [2024-06-17 00:59:06,997][INFO] k: item2vec, type: read_time_mean
# [2024-06-17 00:59:06,998][INFO] clicked_inview_my_cossim/elapsed_seconds: 1/df shape: (1356663, 106)
# [2024-06-17 00:59:24,681][INFO] k: multilingual-e5-large-instruct, cat_col: device_type
# [2024-06-17 00:59:24,682][INFO] add_cossim_by_category/elapsed_seconds: 17/df shape: (1356663, 107)
# [2024-06-17 00:59:40,911][INFO] k: multilingual-e5-large-instruct, cat_col: is_subscriber
# [2024-06-17 00:59:40,912][INFO] add_cossim_by_category/elapsed_seconds: 16/df shape: (1356663, 108)
# [2024-06-17 00:59:56,721][INFO] k: multilingual-e5-large-instruct, cat_col: is_sso_user
# [2024-06-17 00:59:56,724][INFO] add_cossim_by_category/elapsed_seconds: 15/df shape: (1356663, 109)
# [2024-06-17 01:00:00,896][INFO] calculate_inview_counts/elapsed_seconds: 4/df shape: (1356663, 113)
# [2024-06-17 01:00:05,053][INFO] statistic/elapsed_seconds: 4/df shape: (1356663, 404)
# [2024-06-17 01:00:36,766][INFO] Starting Chunk 6
# [2024-06-17 01:00:38,351][INFO] start:feature_engineering
# [2024-06-17 01:00:38,352][INFO] df shape: (1352777, 15)
# [2024-06-17 01:00:39,793][INFO] clicked_history_count/elapsed_seconds: 1/df shape: (1352777, 18)
# [2024-06-17 01:00:42,038][INFO] inview_cooccur/elapsed_seconds: 2/df shape: (1352777, 28)
# [2024-06-17 01:00:42,284][INFO] feat_article_simple/elapsed_seconds: 0/df shape: (1352777, 43)
# [2024-06-17 01:00:42,401][INFO] user_last_impression_publish_time_diff/elapsed_seconds: 0/df shape: (1352777, 44)
# [2024-06-17 01:00:46,284][INFO] article_pop/elapsed_seconds: 3/df shape: (1352777, 72)
# [2024-06-17 01:00:50,692][INFO] add_past_category_ratios/elapsed_seconds: 4/df shape: (1352777, 75)
# [2024-06-17 01:01:05,258][INFO] add_next_impression_id_cossim/elapsed_seconds: 14/df shape: (1352777, 78)
# [2024-06-17 01:01:18,014][INFO] k: multilingual-e5-large-instruct, type: mean
# [2024-06-17 01:01:18,015][INFO] clicked_inview_common_cossim/elapsed_seconds: 12/df shape: (1352777, 80)
# [2024-06-17 01:01:25,113][INFO] k: multilingual-e5-large-instruct, type: mean
# [2024-06-17 01:01:25,114][INFO] category_click_cossim/elapsed_seconds: 7/df shape: (1352777, 81)
# [2024-06-17 01:01:35,677][INFO] k: multilingual-e5-large-instruct, type: scroll_mean
# [2024-06-17 01:01:35,678][INFO] clicked_inview_common_cossim/elapsed_seconds: 10/df shape: (1352777, 82)
# [2024-06-17 01:01:47,246][INFO] k: multilingual-e5-large-instruct, type: scroll_mean
# [2024-06-17 01:01:47,247][INFO] category_click_cossim/elapsed_seconds: 11/df shape: (1352777, 83)
# [2024-06-17 01:01:57,178][INFO] k: multilingual-e5-large-instruct, type: read_time_mean
# [2024-06-17 01:01:57,179][INFO] clicked_inview_common_cossim/elapsed_seconds: 9/df shape: (1352777, 84)
# [2024-06-17 01:02:08,125][INFO] k: multilingual-e5-large-instruct, type: read_time_mean
# [2024-06-17 01:02:08,126][INFO] category_click_cossim/elapsed_seconds: 10/df shape: (1352777, 85)
# [2024-06-17 01:02:27,457][INFO] k: multilingual-e5-large-instruct
# [2024-06-17 01:02:27,458][INFO] inview_my_cossim/elapsed_seconds: 19/df shape: (1352777, 88)
# [2024-06-17 01:03:21,836][INFO] k: multilingual-e5-large-instruct
# [2024-06-17 01:03:21,838][INFO] add_cossim_individual_features/elapsed_seconds: 54/df shape: (1352777, 96)
# [2024-06-17 01:03:23,266][INFO] k: item2vec, type: mean
# [2024-06-17 01:03:23,267][INFO] clicked_inview_my_cossim/elapsed_seconds: 1/df shape: (1352777, 97)
# [2024-06-17 01:03:24,632][INFO] k: item2vec, type: mean
# [2024-06-17 01:03:24,633][INFO] clicked_inview_my_cossim/elapsed_seconds: 1/df shape: (1352777, 98)
# [2024-06-17 01:03:25,925][INFO] k: item2vec, type: mean
# [2024-06-17 01:03:25,926][INFO] clicked_inview_my_cossim/elapsed_seconds: 1/df shape: (1352777, 99)
# [2024-06-17 01:03:27,145][INFO] k: item2vec, type: mean
# [2024-06-17 01:03:27,146][INFO] clicked_inview_my_cossim/elapsed_seconds: 1/df shape: (1352777, 100)
# [2024-06-17 01:03:28,462][INFO] k: item2vec, type: scroll_mean
# [2024-06-17 01:03:28,463][INFO] clicked_inview_my_cossim/elapsed_seconds: 1/df shape: (1352777, 101)
# [2024-06-17 01:03:29,765][INFO] k: item2vec, type: scroll_mean
# [2024-06-17 01:03:29,766][INFO] clicked_inview_my_cossim/elapsed_seconds: 1/df shape: (1352777, 102)
# [2024-06-17 01:03:31,284][INFO] k: item2vec, type: scroll_mean
# [2024-06-17 01:03:31,285][INFO] clicked_inview_my_cossim/elapsed_seconds: 1/df shape: (1352777, 103)
# [2024-06-17 01:03:32,579][INFO] k: item2vec, type: read_time_mean
# [2024-06-17 01:03:32,580][INFO] clicked_inview_my_cossim/elapsed_seconds: 1/df shape: (1352777, 104)
# [2024-06-17 01:03:33,872][INFO] k: item2vec, type: read_time_mean
# [2024-06-17 01:03:33,874][INFO] clicked_inview_my_cossim/elapsed_seconds: 1/df shape: (1352777, 105)
# [2024-06-17 01:03:35,319][INFO] k: item2vec, type: read_time_mean
# [2024-06-17 01:03:35,320][INFO] clicked_inview_my_cossim/elapsed_seconds: 1/df shape: (1352777, 106)
# [2024-06-17 01:03:52,734][INFO] k: multilingual-e5-large-instruct, cat_col: device_type
# [2024-06-17 01:03:52,735][INFO] add_cossim_by_category/elapsed_seconds: 17/df shape: (1352777, 107)
# [2024-06-17 01:04:08,643][INFO] k: multilingual-e5-large-instruct, cat_col: is_subscriber
# [2024-06-17 01:04:08,644][INFO] add_cossim_by_category/elapsed_seconds: 15/df shape: (1352777, 108)
# [2024-06-17 01:04:24,590][INFO] k: multilingual-e5-large-instruct, cat_col: is_sso_user
# [2024-06-17 01:04:24,592][INFO] add_cossim_by_category/elapsed_seconds: 15/df shape: (1352777, 109)
# [2024-06-17 01:04:28,729][INFO] calculate_inview_counts/elapsed_seconds: 4/df shape: (1352777, 113)
# [2024-06-17 01:04:32,956][INFO] statistic/elapsed_seconds: 4/df shape: (1352777, 404)
# [2024-06-17 01:05:05,109][INFO] Starting Chunk 7
# [2024-06-17 01:05:06,720][INFO] start:feature_engineering
# [2024-06-17 01:05:06,721][INFO] df shape: (1328320, 15)
# [2024-06-17 01:05:08,120][INFO] clicked_history_count/elapsed_seconds: 1/df shape: (1328320, 18)
# [2024-06-17 01:05:10,354][INFO] inview_cooccur/elapsed_seconds: 2/df shape: (1328320, 28)
# [2024-06-17 01:05:10,583][INFO] feat_article_simple/elapsed_seconds: 0/df shape: (1328320, 43)
# [2024-06-17 01:05:10,698][INFO] user_last_impression_publish_time_diff/elapsed_seconds: 0/df shape: (1328320, 44)
# [2024-06-17 01:05:14,547][INFO] article_pop/elapsed_seconds: 3/df shape: (1328320, 72)
# [2024-06-17 01:05:18,920][INFO] add_past_category_ratios/elapsed_seconds: 4/df shape: (1328320, 75)
# [2024-06-17 01:05:33,139][INFO] add_next_impression_id_cossim/elapsed_seconds: 14/df shape: (1328320, 78)
# [2024-06-17 01:05:45,666][INFO] k: multilingual-e5-large-instruct, type: mean
# [2024-06-17 01:05:45,668][INFO] clicked_inview_common_cossim/elapsed_seconds: 12/df shape: (1328320, 80)
# [2024-06-17 01:05:52,576][INFO] k: multilingual-e5-large-instruct, type: mean
# [2024-06-17 01:05:52,578][INFO] category_click_cossim/elapsed_seconds: 6/df shape: (1328320, 81)
# [2024-06-17 01:06:02,966][INFO] k: multilingual-e5-large-instruct, type: scroll_mean
# [2024-06-17 01:06:02,969][INFO] clicked_inview_common_cossim/elapsed_seconds: 10/df shape: (1328320, 82)
# [2024-06-17 01:06:14,223][INFO] k: multilingual-e5-large-instruct, type: scroll_mean
# [2024-06-17 01:06:14,224][INFO] category_click_cossim/elapsed_seconds: 11/df shape: (1328320, 83)
# [2024-06-17 01:06:23,976][INFO] k: multilingual-e5-large-instruct, type: read_time_mean
# [2024-06-17 01:06:23,978][INFO] clicked_inview_common_cossim/elapsed_seconds: 9/df shape: (1328320, 84)
# [2024-06-17 01:06:34,669][INFO] k: multilingual-e5-large-instruct, type: read_time_mean
# [2024-06-17 01:06:34,670][INFO] category_click_cossim/elapsed_seconds: 10/df shape: (1328320, 85)
# [2024-06-17 01:06:53,818][INFO] k: multilingual-e5-large-instruct
# [2024-06-17 01:06:53,819][INFO] inview_my_cossim/elapsed_seconds: 19/df shape: (1328320, 88)
# [2024-06-17 01:07:47,238][INFO] k: multilingual-e5-large-instruct
# [2024-06-17 01:07:47,240][INFO] add_cossim_individual_features/elapsed_seconds: 53/df shape: (1328320, 96)
# [2024-06-17 01:07:48,654][INFO] k: item2vec, type: mean
# [2024-06-17 01:07:48,655][INFO] clicked_inview_my_cossim/elapsed_seconds: 1/df shape: (1328320, 97)
# [2024-06-17 01:07:49,979][INFO] k: item2vec, type: mean
# [2024-06-17 01:07:49,980][INFO] clicked_inview_my_cossim/elapsed_seconds: 1/df shape: (1328320, 98)
# [2024-06-17 01:07:51,309][INFO] k: item2vec, type: mean
# [2024-06-17 01:07:51,310][INFO] clicked_inview_my_cossim/elapsed_seconds: 1/df shape: (1328320, 99)
# [2024-06-17 01:07:52,525][INFO] k: item2vec, type: mean
# [2024-06-17 01:07:52,526][INFO] clicked_inview_my_cossim/elapsed_seconds: 1/df shape: (1328320, 100)
# [2024-06-17 01:07:53,822][INFO] k: item2vec, type: scroll_mean
# [2024-06-17 01:07:53,824][INFO] clicked_inview_my_cossim/elapsed_seconds: 1/df shape: (1328320, 101)
# [2024-06-17 01:07:55,167][INFO] k: item2vec, type: scroll_mean
# [2024-06-17 01:07:55,168][INFO] clicked_inview_my_cossim/elapsed_seconds: 1/df shape: (1328320, 102)
# [2024-06-17 01:07:56,681][INFO] k: item2vec, type: scroll_mean
# [2024-06-17 01:07:56,682][INFO] clicked_inview_my_cossim/elapsed_seconds: 1/df shape: (1328320, 103)
# [2024-06-17 01:07:58,009][INFO] k: item2vec, type: read_time_mean
# [2024-06-17 01:07:58,010][INFO] clicked_inview_my_cossim/elapsed_seconds: 1/df shape: (1328320, 104)
# [2024-06-17 01:07:59,270][INFO] k: item2vec, type: read_time_mean
# [2024-06-17 01:07:59,271][INFO] clicked_inview_my_cossim/elapsed_seconds: 1/df shape: (1328320, 105)
# [2024-06-17 01:08:00,723][INFO] k: item2vec, type: read_time_mean
# [2024-06-17 01:08:00,724][INFO] clicked_inview_my_cossim/elapsed_seconds: 1/df shape: (1328320, 106)
# [2024-06-17 01:08:17,789][INFO] k: multilingual-e5-large-instruct, cat_col: device_type
# [2024-06-17 01:08:17,790][INFO] add_cossim_by_category/elapsed_seconds: 17/df shape: (1328320, 107)
# [2024-06-17 01:08:33,279][INFO] k: multilingual-e5-large-instruct, cat_col: is_subscriber
# [2024-06-17 01:08:33,280][INFO] add_cossim_by_category/elapsed_seconds: 15/df shape: (1328320, 108)
# [2024-06-17 01:08:48,770][INFO] k: multilingual-e5-large-instruct, cat_col: is_sso_user
# [2024-06-17 01:08:48,771][INFO] add_cossim_by_category/elapsed_seconds: 15/df shape: (1328320, 109)
# [2024-06-17 01:08:52,850][INFO] calculate_inview_counts/elapsed_seconds: 4/df shape: (1328320, 113)
# [2024-06-17 01:08:56,971][INFO] statistic/elapsed_seconds: 4/df shape: (1328320, 404)
# [2024-06-17 01:09:28,548][INFO] Starting Chunk 8
# [2024-06-17 01:09:30,148][INFO] start:feature_engineering
# [2024-06-17 01:09:30,150][INFO] df shape: (1338892, 15)
# [2024-06-17 01:09:31,507][INFO] clicked_history_count/elapsed_seconds: 1/df shape: (1338892, 18)
# [2024-06-17 01:09:33,709][INFO] inview_cooccur/elapsed_seconds: 2/df shape: (1338892, 28)
# [2024-06-17 01:09:33,945][INFO] feat_article_simple/elapsed_seconds: 0/df shape: (1338892, 43)
# [2024-06-17 01:09:34,056][INFO] user_last_impression_publish_time_diff/elapsed_seconds: 0/df shape: (1338892, 44)
# [2024-06-17 01:09:37,867][INFO] article_pop/elapsed_seconds: 3/df shape: (1338892, 72)
# [2024-06-17 01:09:42,248][INFO] add_past_category_ratios/elapsed_seconds: 4/df shape: (1338892, 75)
# [2024-06-17 01:09:56,707][INFO] add_next_impression_id_cossim/elapsed_seconds: 14/df shape: (1338892, 78)
# [2024-06-17 01:10:09,476][INFO] k: multilingual-e5-large-instruct, type: mean
# [2024-06-17 01:10:09,479][INFO] clicked_inview_common_cossim/elapsed_seconds: 12/df shape: (1338892, 80)
# [2024-06-17 01:10:16,498][INFO] k: multilingual-e5-large-instruct, type: mean
# [2024-06-17 01:10:16,499][INFO] category_click_cossim/elapsed_seconds: 7/df shape: (1338892, 81)
# [2024-06-17 01:10:26,843][INFO] k: multilingual-e5-large-instruct, type: scroll_mean
# [2024-06-17 01:10:26,844][INFO] clicked_inview_common_cossim/elapsed_seconds: 10/df shape: (1338892, 82)
# [2024-06-17 01:10:38,251][INFO] k: multilingual-e5-large-instruct, type: scroll_mean
# [2024-06-17 01:10:38,253][INFO] category_click_cossim/elapsed_seconds: 11/df shape: (1338892, 83)
# [2024-06-17 01:10:48,071][INFO] k: multilingual-e5-large-instruct, type: read_time_mean
# [2024-06-17 01:10:48,072][INFO] clicked_inview_common_cossim/elapsed_seconds: 9/df shape: (1338892, 84)
# [2024-06-17 01:10:58,844][INFO] k: multilingual-e5-large-instruct, type: read_time_mean
# [2024-06-17 01:10:58,845][INFO] category_click_cossim/elapsed_seconds: 10/df shape: (1338892, 85)
# [2024-06-17 01:11:17,921][INFO] k: multilingual-e5-large-instruct
# [2024-06-17 01:11:17,923][INFO] inview_my_cossim/elapsed_seconds: 19/df shape: (1338892, 88)
# [2024-06-17 01:12:11,710][INFO] k: multilingual-e5-large-instruct
# [2024-06-17 01:12:11,712][INFO] add_cossim_individual_features/elapsed_seconds: 53/df shape: (1338892, 96)
# [2024-06-17 01:12:13,165][INFO] k: item2vec, type: mean
# [2024-06-17 01:12:13,166][INFO] clicked_inview_my_cossim/elapsed_seconds: 1/df shape: (1338892, 97)
# [2024-06-17 01:12:14,454][INFO] k: item2vec, type: mean
# [2024-06-17 01:12:14,455][INFO] clicked_inview_my_cossim/elapsed_seconds: 1/df shape: (1338892, 98)
# [2024-06-17 01:12:15,783][INFO] k: item2vec, type: mean
# [2024-06-17 01:12:15,784][INFO] clicked_inview_my_cossim/elapsed_seconds: 1/df shape: (1338892, 99)
# [2024-06-17 01:12:16,984][INFO] k: item2vec, type: mean
# [2024-06-17 01:12:16,985][INFO] clicked_inview_my_cossim/elapsed_seconds: 1/df shape: (1338892, 100)
# [2024-06-17 01:12:18,265][INFO] k: item2vec, type: scroll_mean
# [2024-06-17 01:12:18,267][INFO] clicked_inview_my_cossim/elapsed_seconds: 1/df shape: (1338892, 101)
# [2024-06-17 01:12:19,514][INFO] k: item2vec, type: scroll_mean
# [2024-06-17 01:12:19,515][INFO] clicked_inview_my_cossim/elapsed_seconds: 1/df shape: (1338892, 102)
# [2024-06-17 01:12:21,021][INFO] k: item2vec, type: scroll_mean
# [2024-06-17 01:12:21,023][INFO] clicked_inview_my_cossim/elapsed_seconds: 1/df shape: (1338892, 103)
# [2024-06-17 01:12:22,318][INFO] k: item2vec, type: read_time_mean
# [2024-06-17 01:12:22,319][INFO] clicked_inview_my_cossim/elapsed_seconds: 1/df shape: (1338892, 104)
# [2024-06-17 01:12:23,588][INFO] k: item2vec, type: read_time_mean
# [2024-06-17 01:12:23,589][INFO] clicked_inview_my_cossim/elapsed_seconds: 1/df shape: (1338892, 105)
# [2024-06-17 01:12:25,043][INFO] k: item2vec, type: read_time_mean
# [2024-06-17 01:12:25,045][INFO] clicked_inview_my_cossim/elapsed_seconds: 1/df shape: (1338892, 106)
# [2024-06-17 01:12:42,317][INFO] k: multilingual-e5-large-instruct, cat_col: device_type
# [2024-06-17 01:12:42,318][INFO] add_cossim_by_category/elapsed_seconds: 17/df shape: (1338892, 107)
# [2024-06-17 01:12:57,824][INFO] k: multilingual-e5-large-instruct, cat_col: is_subscriber
# [2024-06-17 01:12:57,825][INFO] add_cossim_by_category/elapsed_seconds: 15/df shape: (1338892, 108)
# [2024-06-17 01:13:13,558][INFO] k: multilingual-e5-large-instruct, cat_col: is_sso_user
# [2024-06-17 01:13:13,560][INFO] add_cossim_by_category/elapsed_seconds: 15/df shape: (1338892, 109)
# [2024-06-17 01:13:17,613][INFO] calculate_inview_counts/elapsed_seconds: 4/df shape: (1338892, 113)
# [2024-06-17 01:13:21,758][INFO] statistic/elapsed_seconds: 4/df shape: (1338892, 404)
# [2024-06-17 01:13:52,988][INFO] Starting Chunk 9
# [2024-06-17 01:13:54,591][INFO] start:feature_engineering
# [2024-06-17 01:13:54,592][INFO] df shape: (1312535, 15)
# [2024-06-17 01:13:55,987][INFO] clicked_history_count/elapsed_seconds: 1/df shape: (1312535, 18)
# [2024-06-17 01:13:58,211][INFO] inview_cooccur/elapsed_seconds: 2/df shape: (1312535, 28)
# [2024-06-17 01:13:58,452][INFO] feat_article_simple/elapsed_seconds: 0/df shape: (1312535, 43)
# [2024-06-17 01:13:58,562][INFO] user_last_impression_publish_time_diff/elapsed_seconds: 0/df shape: (1312535, 44)
# [2024-06-17 01:14:02,499][INFO] article_pop/elapsed_seconds: 3/df shape: (1312535, 72)
# [2024-06-17 01:14:06,589][INFO] add_past_category_ratios/elapsed_seconds: 4/df shape: (1312535, 75)
# [2024-06-17 01:14:20,582][INFO] add_next_impression_id_cossim/elapsed_seconds: 13/df shape: (1312535, 78)
# [2024-06-17 01:14:33,483][INFO] k: multilingual-e5-large-instruct, type: mean
# [2024-06-17 01:14:33,484][INFO] clicked_inview_common_cossim/elapsed_seconds: 12/df shape: (1312535, 80)
# [2024-06-17 01:14:40,542][INFO] k: multilingual-e5-large-instruct, type: mean
# [2024-06-17 01:14:40,543][INFO] category_click_cossim/elapsed_seconds: 7/df shape: (1312535, 81)
# [2024-06-17 01:14:50,942][INFO] k: multilingual-e5-large-instruct, type: scroll_mean
# [2024-06-17 01:14:50,944][INFO] clicked_inview_common_cossim/elapsed_seconds: 10/df shape: (1312535, 82)
# [2024-06-17 01:15:02,535][INFO] k: multilingual-e5-large-instruct, type: scroll_mean
# [2024-06-17 01:15:02,536][INFO] category_click_cossim/elapsed_seconds: 11/df shape: (1312535, 83)
# [2024-06-17 01:15:12,369][INFO] k: multilingual-e5-large-instruct, type: read_time_mean
# [2024-06-17 01:15:12,370][INFO] clicked_inview_common_cossim/elapsed_seconds: 9/df shape: (1312535, 84)
# [2024-06-17 01:15:23,155][INFO] k: multilingual-e5-large-instruct, type: read_time_mean
# [2024-06-17 01:15:23,157][INFO] category_click_cossim/elapsed_seconds: 10/df shape: (1312535, 85)
# [2024-06-17 01:15:42,227][INFO] k: multilingual-e5-large-instruct
# [2024-06-17 01:15:42,228][INFO] inview_my_cossim/elapsed_seconds: 19/df shape: (1312535, 88)
# [2024-06-17 01:16:35,106][INFO] k: multilingual-e5-large-instruct
# [2024-06-17 01:16:35,108][INFO] add_cossim_individual_features/elapsed_seconds: 52/df shape: (1312535, 96)
# [2024-06-17 01:16:36,681][INFO] k: item2vec, type: mean
# [2024-06-17 01:16:36,682][INFO] clicked_inview_my_cossim/elapsed_seconds: 1/df shape: (1312535, 97)
# [2024-06-17 01:16:38,014][INFO] k: item2vec, type: mean
# [2024-06-17 01:16:38,015][INFO] clicked_inview_my_cossim/elapsed_seconds: 1/df shape: (1312535, 98)
# [2024-06-17 01:16:39,384][INFO] k: item2vec, type: mean
# [2024-06-17 01:16:39,385][INFO] clicked_inview_my_cossim/elapsed_seconds: 1/df shape: (1312535, 99)
# [2024-06-17 01:16:40,670][INFO] k: item2vec, type: mean
# [2024-06-17 01:16:40,672][INFO] clicked_inview_my_cossim/elapsed_seconds: 1/df shape: (1312535, 100)
# [2024-06-17 01:16:42,028][INFO] k: item2vec, type: scroll_mean
# [2024-06-17 01:16:42,029][INFO] clicked_inview_my_cossim/elapsed_seconds: 1/df shape: (1312535, 101)
# [2024-06-17 01:16:43,338][INFO] k: item2vec, type: scroll_mean
# [2024-06-17 01:16:43,339][INFO] clicked_inview_my_cossim/elapsed_seconds: 1/df shape: (1312535, 102)
# [2024-06-17 01:16:44,855][INFO] k: item2vec, type: scroll_mean
# [2024-06-17 01:16:44,856][INFO] clicked_inview_my_cossim/elapsed_seconds: 1/df shape: (1312535, 103)
# [2024-06-17 01:16:46,151][INFO] k: item2vec, type: read_time_mean
# [2024-06-17 01:16:46,152][INFO] clicked_inview_my_cossim/elapsed_seconds: 1/df shape: (1312535, 104)
# [2024-06-17 01:16:47,489][INFO] k: item2vec, type: read_time_mean
# [2024-06-17 01:16:47,490][INFO] clicked_inview_my_cossim/elapsed_seconds: 1/df shape: (1312535, 105)
# [2024-06-17 01:16:49,110][INFO] k: item2vec, type: read_time_mean
# [2024-06-17 01:16:49,112][INFO] clicked_inview_my_cossim/elapsed_seconds: 1/df shape: (1312535, 106)
# [2024-06-17 01:17:08,759][INFO] k: multilingual-e5-large-instruct, cat_col: device_type
# [2024-06-17 01:17:08,760][INFO] add_cossim_by_category/elapsed_seconds: 19/df shape: (1312535, 107)
# [2024-06-17 01:17:28,372][INFO] k: multilingual-e5-large-instruct, cat_col: is_subscriber
# [2024-06-17 01:17:28,373][INFO] add_cossim_by_category/elapsed_seconds: 19/df shape: (1312535, 108)
# [2024-06-17 01:17:48,322][INFO] k: multilingual-e5-large-instruct, cat_col: is_sso_user
# [2024-06-17 01:17:48,323][INFO] add_cossim_by_category/elapsed_seconds: 19/df shape: (1312535, 109)
# [2024-06-17 01:17:52,609][INFO] calculate_inview_counts/elapsed_seconds: 4/df shape: (1312535, 113)
# [2024-06-17 01:17:56,957][INFO] statistic/elapsed_seconds: 4/df shape: (1312535, 404)
# [2024-06-17 01:18:30,751][INFO] Starting Chunk 10
# [2024-06-17 01:18:32,877][INFO] start:feature_engineering
# [2024-06-17 01:18:32,879][INFO] df shape: (1343072, 15)
# [2024-06-17 01:18:34,624][INFO] clicked_history_count/elapsed_seconds: 1/df shape: (1343072, 18)
# [2024-06-17 01:18:36,772][INFO] inview_cooccur/elapsed_seconds: 2/df shape: (1343072, 28)
# [2024-06-17 01:18:37,005][INFO] feat_article_simple/elapsed_seconds: 0/df shape: (1343072, 43)
# [2024-06-17 01:18:37,122][INFO] user_last_impression_publish_time_diff/elapsed_seconds: 0/df shape: (1343072, 44)
# [2024-06-17 01:18:41,045][INFO] article_pop/elapsed_seconds: 3/df shape: (1343072, 72)
# [2024-06-17 01:18:45,705][INFO] add_past_category_ratios/elapsed_seconds: 4/df shape: (1343072, 75)
# [2024-06-17 01:19:01,830][INFO] add_next_impression_id_cossim/elapsed_seconds: 16/df shape: (1343072, 78)
# [2024-06-17 01:19:19,286][INFO] k: multilingual-e5-large-instruct, type: mean
# [2024-06-17 01:19:19,287][INFO] clicked_inview_common_cossim/elapsed_seconds: 17/df shape: (1343072, 80)
# [2024-06-17 01:19:28,391][INFO] k: multilingual-e5-large-instruct, type: mean
# [2024-06-17 01:19:28,393][INFO] category_click_cossim/elapsed_seconds: 9/df shape: (1343072, 81)
# [2024-06-17 01:19:41,938][INFO] k: multilingual-e5-large-instruct, type: scroll_mean
# ...
# [2024-06-17 08:55:58,931][INFO] clicked_inview_my_cossim/elapsed_seconds: 1/df shape: (1325660, 99)
# [2024-06-17 08:56:00,181][INFO] k: item2vec, type: mean
# [2024-06-17 08:56:00,182][INFO] clicked_inview_my_cossim/elapsed_seconds: 1/df shape: (1325660, 100)
# [2024-06-17 08:56:01,688][INFO] k: item2vec, type: scroll_mean
# [2024-06-17 08:56:01,691][INFO] clicked_inview_my_cossim/elapsed_seconds: 1/df shape: (1325660, 101)
# [2024-06-17 08:56:03,270][INFO] k: item2vec, type: scroll_mean
# [2024-06-17 08:56:03,272][INFO] clicked_inview_my_cossim/elapsed_seconds: 1/df shape: (1325660, 102)
# [2024-06-17 08:56:05,083][INFO] k: item2vec, type: scroll_mean
# [2024-06-17 08:56:05,085][INFO] clicked_inview_my_cossim/elapsed_seconds: 1/df shape: (1325660, 103)
# [2024-06-17 08:56:06,478][INFO] k: item2vec, type: read_time_mean
# [2024-06-17 08:56:06,479][INFO] clicked_inview_my_cossim/elapsed_seconds: 1/df shape: (1325660, 104)
# [2024-06-17 08:56:07,778][INFO] k: item2vec, type: read_time_mean
# [2024-06-17 08:56:07,779][INFO] clicked_inview_my_cossim/elapsed_seconds: 1/df shape: (1325660, 105)
# [2024-06-17 08:56:09,441][INFO] k: item2vec, type: read_time_mean
# [2024-06-17 08:56:09,443][INFO] clicked_inview_my_cossim/elapsed_seconds: 1/df shape: (1325660, 106)
# [2024-06-17 08:56:33,451][INFO] k: multilingual-e5-large-instruct, cat_col: device_type
# [2024-06-17 08:56:33,453][INFO] add_cossim_by_category/elapsed_seconds: 24/df shape: (1325660, 107)
# [2024-06-17 08:56:51,487][INFO] k: multilingual-e5-large-instruct, cat_col: is_subscriber
# [2024-06-17 08:56:51,489][INFO] add_cossim_by_category/elapsed_seconds: 18/df shape: (1325660, 108)
# [2024-06-17 08:57:15,640][INFO] k: multilingual-e5-large-instruct, cat_col: is_sso_user
# [2024-06-17 08:57:15,642][INFO] add_cossim_by_category/elapsed_seconds: 24/df shape: (1325660, 109)
# [2024-06-17 08:57:21,720][INFO] calculate_inview_counts/elapsed_seconds: 6/df shape: (1325660, 113)
# [2024-06-17 08:57:28,221][INFO] statistic/elapsed_seconds: 6/df shape: (1325660, 404)
# [2024-06-17 08:58:08,050][INFO] Starting Chunk 97
# [2024-06-17 08:58:09,775][INFO] start:feature_engineering
# [2024-06-17 08:58:09,776][INFO] df shape: (1336042, 15)
# [2024-06-17 08:58:11,264][INFO] clicked_history_count/elapsed_seconds: 1/df shape: (1336042, 18)
# [2024-06-17 08:58:13,524][INFO] inview_cooccur/elapsed_seconds: 2/df shape: (1336042, 28)
# [2024-06-17 08:58:13,764][INFO] feat_article_simple/elapsed_seconds: 0/df shape: (1336042, 43)
# [2024-06-17 08:58:13,876][INFO] user_last_impression_publish_time_diff/elapsed_seconds: 0/df shape: (1336042, 44)
# [2024-06-17 08:58:17,675][INFO] article_pop/elapsed_seconds: 3/df shape: (1336042, 72)
# [2024-06-17 08:58:21,898][INFO] add_past_category_ratios/elapsed_seconds: 4/df shape: (1336042, 75)
# [2024-06-17 08:58:37,398][INFO] add_next_impression_id_cossim/elapsed_seconds: 15/df shape: (1336042, 78)
# [2024-06-17 08:58:52,729][INFO] k: multilingual-e5-large-instruct, type: mean
# [2024-06-17 08:58:52,730][INFO] clicked_inview_common_cossim/elapsed_seconds: 15/df shape: (1336042, 80)
# [2024-06-17 08:59:01,897][INFO] k: multilingual-e5-large-instruct, type: mean
# [2024-06-17 08:59:01,899][INFO] category_click_cossim/elapsed_seconds: 9/df shape: (1336042, 81)
# [2024-06-17 08:59:14,818][INFO] k: multilingual-e5-large-instruct, type: scroll_mean
# [2024-06-17 08:59:14,820][INFO] clicked_inview_common_cossim/elapsed_seconds: 12/df shape: (1336042, 82)
# [2024-06-17 08:59:31,747][INFO] k: multilingual-e5-large-instruct, type: scroll_mean
# [2024-06-17 08:59:31,748][INFO] category_click_cossim/elapsed_seconds: 16/df shape: (1336042, 83)
# [2024-06-17 08:59:43,769][INFO] k: multilingual-e5-large-instruct, type: read_time_mean
# [2024-06-17 08:59:43,770][INFO] clicked_inview_common_cossim/elapsed_seconds: 12/df shape: (1336042, 84)
# [2024-06-17 08:59:55,443][INFO] k: multilingual-e5-large-instruct, type: read_time_mean
# [2024-06-17 08:59:55,445][INFO] category_click_cossim/elapsed_seconds: 11/df shape: (1336042, 85)
# [2024-06-17 09:00:20,466][INFO] k: multilingual-e5-large-instruct
# [2024-06-17 09:00:20,467][INFO] inview_my_cossim/elapsed_seconds: 25/df shape: (1336042, 88)
# [2024-06-17 09:01:20,584][INFO] k: multilingual-e5-large-instruct
# [2024-06-17 09:01:20,585][INFO] add_cossim_individual_features/elapsed_seconds: 60/df shape: (1336042, 96)
# [2024-06-17 09:01:22,212][INFO] k: item2vec, type: mean
# [2024-06-17 09:01:22,214][INFO] clicked_inview_my_cossim/elapsed_seconds: 1/df shape: (1336042, 97)
# [2024-06-17 09:01:23,546][INFO] k: item2vec, type: mean
# [2024-06-17 09:01:23,547][INFO] clicked_inview_my_cossim/elapsed_seconds: 1/df shape: (1336042, 98)
# [2024-06-17 09:01:24,824][INFO] k: item2vec, type: mean
# [2024-06-17 09:01:24,826][INFO] clicked_inview_my_cossim/elapsed_seconds: 1/df shape: (1336042, 99)
# [2024-06-17 09:01:26,007][INFO] k: item2vec, type: mean
# [2024-06-17 09:01:26,008][INFO] clicked_inview_my_cossim/elapsed_seconds: 1/df shape: (1336042, 100)
# [2024-06-17 09:01:27,291][INFO] k: item2vec, type: scroll_mean
# [2024-06-17 09:01:27,293][INFO] clicked_inview_my_cossim/elapsed_seconds: 1/df shape: (1336042, 101)
# [2024-06-17 09:01:28,579][INFO] k: item2vec, type: scroll_mean
# [2024-06-17 09:01:28,580][INFO] clicked_inview_my_cossim/elapsed_seconds: 1/df shape: (1336042, 102)
# [2024-06-17 09:01:30,061][INFO] k: item2vec, type: scroll_mean
# [2024-06-17 09:01:30,062][INFO] clicked_inview_my_cossim/elapsed_seconds: 1/df shape: (1336042, 103)
# [2024-06-17 09:01:31,386][INFO] k: item2vec, type: read_time_mean
# [2024-06-17 09:01:31,387][INFO] clicked_inview_my_cossim/elapsed_seconds: 1/df shape: (1336042, 104)
# [2024-06-17 09:01:32,693][INFO] k: item2vec, type: read_time_mean
# [2024-06-17 09:01:32,694][INFO] clicked_inview_my_cossim/elapsed_seconds: 1/df shape: (1336042, 105)
# [2024-06-17 09:01:34,143][INFO] k: item2vec, type: read_time_mean
# [2024-06-17 09:01:34,144][INFO] clicked_inview_my_cossim/elapsed_seconds: 1/df shape: (1336042, 106)
# [2024-06-17 09:01:51,886][INFO] k: multilingual-e5-large-instruct, cat_col: device_type
# [2024-06-17 09:01:51,888][INFO] add_cossim_by_category/elapsed_seconds: 17/df shape: (1336042, 107)
# [2024-06-17 09:02:08,448][INFO] k: multilingual-e5-large-instruct, cat_col: is_subscriber
# [2024-06-17 09:02:08,450][INFO] add_cossim_by_category/elapsed_seconds: 16/df shape: (1336042, 108)
# [2024-06-17 09:02:26,672][INFO] k: multilingual-e5-large-instruct, cat_col: is_sso_user
# [2024-06-17 09:02:26,674][INFO] add_cossim_by_category/elapsed_seconds: 18/df shape: (1336042, 109)
# [2024-06-17 09:02:31,350][INFO] calculate_inview_counts/elapsed_seconds: 4/df shape: (1336042, 113)
# [2024-06-17 09:02:36,460][INFO] statistic/elapsed_seconds: 5/df shape: (1336042, 404)
# [2024-06-17 09:03:15,951][INFO] Starting Chunk 98
# [2024-06-17 09:03:17,800][INFO] start:feature_engineering
# [2024-06-17 09:03:17,801][INFO] df shape: (1333149, 15)
# [2024-06-17 09:03:19,642][INFO] clicked_history_count/elapsed_seconds: 1/df shape: (1333149, 18)
# [2024-06-17 09:03:22,310][INFO] inview_cooccur/elapsed_seconds: 2/df shape: (1333149, 28)
# [2024-06-17 09:03:22,528][INFO] feat_article_simple/elapsed_seconds: 0/df shape: (1333149, 43)
# [2024-06-17 09:03:22,638][INFO] user_last_impression_publish_time_diff/elapsed_seconds: 0/df shape: (1333149, 44)
# [2024-06-17 09:03:26,443][INFO] article_pop/elapsed_seconds: 3/df shape: (1333149, 72)
# [2024-06-17 09:03:31,165][INFO] add_past_category_ratios/elapsed_seconds: 4/df shape: (1333149, 75)
# [2024-06-17 09:03:49,140][INFO] add_next_impression_id_cossim/elapsed_seconds: 17/df shape: (1333149, 78)
# [2024-06-17 09:04:03,258][INFO] k: multilingual-e5-large-instruct, type: mean
# [2024-06-17 09:04:03,260][INFO] clicked_inview_common_cossim/elapsed_seconds: 14/df shape: (1333149, 80)
# [2024-06-17 09:04:13,395][INFO] k: multilingual-e5-large-instruct, type: mean
# [2024-06-17 09:04:13,396][INFO] category_click_cossim/elapsed_seconds: 10/df shape: (1333149, 81)
# [2024-06-17 09:04:25,312][INFO] k: multilingual-e5-large-instruct, type: scroll_mean
# [2024-06-17 09:04:25,313][INFO] clicked_inview_common_cossim/elapsed_seconds: 11/df shape: (1333149, 82)
# [2024-06-17 09:04:40,115][INFO] k: multilingual-e5-large-instruct, type: scroll_mean
# [2024-06-17 09:04:40,116][INFO] category_click_cossim/elapsed_seconds: 14/df shape: (1333149, 83)
# [2024-06-17 09:04:53,199][INFO] k: multilingual-e5-large-instruct, type: read_time_mean
# [2024-06-17 09:04:53,201][INFO] clicked_inview_common_cossim/elapsed_seconds: 13/df shape: (1333149, 84)
# [2024-06-17 09:05:07,879][INFO] k: multilingual-e5-large-instruct, type: read_time_mean
# [2024-06-17 09:05:07,880][INFO] category_click_cossim/elapsed_seconds: 14/df shape: (1333149, 85)
# [2024-06-17 09:05:32,033][INFO] k: multilingual-e5-large-instruct
# [2024-06-17 09:05:32,034][INFO] inview_my_cossim/elapsed_seconds: 24/df shape: (1333149, 88)
# [2024-06-17 09:06:38,328][INFO] k: multilingual-e5-large-instruct
# [2024-06-17 09:06:38,329][INFO] add_cossim_individual_features/elapsed_seconds: 66/df shape: (1333149, 96)
# [2024-06-17 09:06:39,945][INFO] k: item2vec, type: mean
# [2024-06-17 09:06:39,947][INFO] clicked_inview_my_cossim/elapsed_seconds: 1/df shape: (1333149, 97)
# [2024-06-17 09:06:41,465][INFO] k: item2vec, type: mean
# [2024-06-17 09:06:41,466][INFO] clicked_inview_my_cossim/elapsed_seconds: 1/df shape: (1333149, 98)
# [2024-06-17 09:06:42,687][INFO] k: item2vec, type: mean
# [2024-06-17 09:06:42,689][INFO] clicked_inview_my_cossim/elapsed_seconds: 1/df shape: (1333149, 99)
# [2024-06-17 09:06:43,871][INFO] k: item2vec, type: mean
# [2024-06-17 09:06:43,872][INFO] clicked_inview_my_cossim/elapsed_seconds: 1/df shape: (1333149, 100)
# [2024-06-17 09:06:45,137][INFO] k: item2vec, type: scroll_mean
# [2024-06-17 09:06:45,139][INFO] clicked_inview_my_cossim/elapsed_seconds: 1/df shape: (1333149, 101)
# [2024-06-17 09:06:46,464][INFO] k: item2vec, type: scroll_mean
# [2024-06-17 09:06:46,465][INFO] clicked_inview_my_cossim/elapsed_seconds: 1/df shape: (1333149, 102)
# [2024-06-17 09:06:47,973][INFO] k: item2vec, type: scroll_mean
# [2024-06-17 09:06:47,974][INFO] clicked_inview_my_cossim/elapsed_seconds: 1/df shape: (1333149, 103)
# [2024-06-17 09:06:49,192][INFO] k: item2vec, type: read_time_mean
# [2024-06-17 09:06:49,193][INFO] clicked_inview_my_cossim/elapsed_seconds: 1/df shape: (1333149, 104)
# [2024-06-17 09:06:50,558][INFO] k: item2vec, type: read_time_mean
# [2024-06-17 09:06:50,560][INFO] clicked_inview_my_cossim/elapsed_seconds: 1/df shape: (1333149, 105)
# [2024-06-17 09:06:51,994][INFO] k: item2vec, type: read_time_mean
# [2024-06-17 09:06:51,995][INFO] clicked_inview_my_cossim/elapsed_seconds: 1/df shape: (1333149, 106)
# [2024-06-17 09:07:10,679][INFO] k: multilingual-e5-large-instruct, cat_col: device_type
# [2024-06-17 09:07:10,681][INFO] add_cossim_by_category/elapsed_seconds: 18/df shape: (1333149, 107)
# [2024-06-17 09:07:28,173][INFO] k: multilingual-e5-large-instruct, cat_col: is_subscriber
# [2024-06-17 09:07:28,175][INFO] add_cossim_by_category/elapsed_seconds: 17/df shape: (1333149, 108)
# [2024-06-17 09:07:46,607][INFO] k: multilingual-e5-large-instruct, cat_col: is_sso_user
# [2024-06-17 09:07:46,609][INFO] add_cossim_by_category/elapsed_seconds: 18/df shape: (1333149, 109)
# [2024-06-17 09:07:50,426][INFO] calculate_inview_counts/elapsed_seconds: 3/df shape: (1333149, 113)
# [2024-06-17 09:07:54,708][INFO] statistic/elapsed_seconds: 4/df shape: (1333149, 404)
# [2024-06-17 09:08:32,485][INFO] Starting Chunk 99
# [2024-06-17 09:08:34,118][INFO] start:feature_engineering
# [2024-06-17 09:08:34,120][INFO] df shape: (1342014, 15)
# [2024-06-17 09:08:36,025][INFO] clicked_history_count/elapsed_seconds: 1/df shape: (1342014, 18)
# [2024-06-17 09:08:38,349][INFO] inview_cooccur/elapsed_seconds: 2/df shape: (1342014, 28)
# [2024-06-17 09:08:38,614][INFO] feat_article_simple/elapsed_seconds: 0/df shape: (1342014, 43)
# [2024-06-17 09:08:38,735][INFO] user_last_impression_publish_time_diff/elapsed_seconds: 0/df shape: (1342014, 44)
# [2024-06-17 09:08:44,422][INFO] article_pop/elapsed_seconds: 5/df shape: (1342014, 72)
# [2024-06-17 09:08:51,222][INFO] add_past_category_ratios/elapsed_seconds: 6/df shape: (1342014, 75)
# [2024-06-17 09:09:06,764][INFO] add_next_impression_id_cossim/elapsed_seconds: 15/df shape: (1342014, 78)
# [2024-06-17 09:09:26,444][INFO] k: multilingual-e5-large-instruct, type: mean
# [2024-06-17 09:09:26,446][INFO] clicked_inview_common_cossim/elapsed_seconds: 19/df shape: (1342014, 80)
# [2024-06-17 09:09:34,045][INFO] k: multilingual-e5-large-instruct, type: mean
# [2024-06-17 09:09:34,048][INFO] category_click_cossim/elapsed_seconds: 7/df shape: (1342014, 81)
# [2024-06-17 09:09:46,301][INFO] k: multilingual-e5-large-instruct, type: scroll_mean
# [2024-06-17 09:09:46,302][INFO] clicked_inview_common_cossim/elapsed_seconds: 12/df shape: (1342014, 82)
# [2024-06-17 09:09:59,361][INFO] k: multilingual-e5-large-instruct, type: scroll_mean
# [2024-06-17 09:09:59,362][INFO] category_click_cossim/elapsed_seconds: 13/df shape: (1342014, 83)
# [2024-06-17 09:10:10,480][INFO] k: multilingual-e5-large-instruct, type: read_time_mean
# [2024-06-17 09:10:10,481][INFO] clicked_inview_common_cossim/elapsed_seconds: 11/df shape: (1342014, 84)
# [2024-06-17 09:10:22,246][INFO] k: multilingual-e5-large-instruct, type: read_time_mean
# [2024-06-17 09:10:22,248][INFO] category_click_cossim/elapsed_seconds: 11/df shape: (1342014, 85)
# [2024-06-17 09:10:42,953][INFO] k: multilingual-e5-large-instruct
# [2024-06-17 09:10:42,955][INFO] inview_my_cossim/elapsed_seconds: 20/df shape: (1342014, 88)
# [2024-06-17 09:11:47,162][INFO] k: multilingual-e5-large-instruct
# [2024-06-17 09:11:47,163][INFO] add_cossim_individual_features/elapsed_seconds: 64/df shape: (1342014, 96)
# [2024-06-17 09:11:48,663][INFO] k: item2vec, type: mean
# [2024-06-17 09:11:48,665][INFO] clicked_inview_my_cossim/elapsed_seconds: 1/df shape: (1342014, 97)
# [2024-06-17 09:11:49,995][INFO] k: item2vec, type: mean
# [2024-06-17 09:11:49,997][INFO] clicked_inview_my_cossim/elapsed_seconds: 1/df shape: (1342014, 98)
# [2024-06-17 09:11:51,496][INFO] k: item2vec, type: mean
# [2024-06-17 09:11:51,498][INFO] clicked_inview_my_cossim/elapsed_seconds: 1/df shape: (1342014, 99)
# [2024-06-17 09:11:53,111][INFO] k: item2vec, type: mean
# [2024-06-17 09:11:53,112][INFO] clicked_inview_my_cossim/elapsed_seconds: 1/df shape: (1342014, 100)
# [2024-06-17 09:11:54,495][INFO] k: item2vec, type: scroll_mean
# [2024-06-17 09:11:54,496][INFO] clicked_inview_my_cossim/elapsed_seconds: 1/df shape: (1342014, 101)
# [2024-06-17 09:11:55,960][INFO] k: item2vec, type: scroll_mean
# [2024-06-17 09:11:55,961][INFO] clicked_inview_my_cossim/elapsed_seconds: 1/df shape: (1342014, 102)
# [2024-06-17 09:11:57,784][INFO] k: item2vec, type: scroll_mean
# [2024-06-17 09:11:57,786][INFO] clicked_inview_my_cossim/elapsed_seconds: 1/df shape: (1342014, 103)
# [2024-06-17 09:11:59,153][INFO] k: item2vec, type: read_time_mean
# [2024-06-17 09:11:59,155][INFO] clicked_inview_my_cossim/elapsed_seconds: 1/df shape: (1342014, 104)
# [2024-06-17 09:12:00,544][INFO] k: item2vec, type: read_time_mean
# [2024-06-17 09:12:00,545][INFO] clicked_inview_my_cossim/elapsed_seconds: 1/df shape: (1342014, 105)
# [2024-06-17 09:12:02,013][INFO] k: item2vec, type: read_time_mean
# [2024-06-17 09:12:02,014][INFO] clicked_inview_my_cossim/elapsed_seconds: 1/df shape: (1342014, 106)
# [2024-06-17 09:12:21,763][INFO] k: multilingual-e5-large-instruct, cat_col: device_type
# [2024-06-17 09:12:21,764][INFO] add_cossim_by_category/elapsed_seconds: 19/df shape: (1342014, 107)
# [2024-06-17 09:12:39,448][INFO] k: multilingual-e5-large-instruct, cat_col: is_subscriber
# [2024-06-17 09:12:39,450][INFO] add_cossim_by_category/elapsed_seconds: 17/df shape: (1342014, 108)
# [2024-06-17 09:12:58,443][INFO] k: multilingual-e5-large-instruct, cat_col: is_sso_user
# [2024-06-17 09:12:58,444][INFO] add_cossim_by_category/elapsed_seconds: 18/df shape: (1342014, 109)
# [2024-06-17 09:13:02,703][INFO] calculate_inview_counts/elapsed_seconds: 4/df shape: (1342014, 113)
# [2024-06-17 09:13:07,752][INFO] statistic/elapsed_seconds: 5/df shape: (1342014, 404)

# %% [markdown]
# # Valid

# %%
n_chunks = 100

val_df = get_target_df(val_behaviors)
unique_user_ids = val_df["user_id"].unique().to_numpy()

np.random.shuffle(unique_user_ids)
user_id_splits = np.array_split(unique_user_ids, n_chunks)

for _chunk in range(n_chunks):
    
    logger.info(f"Starting Chunk {_chunk}")

    df_chunk = val_df.filter(pl.col("user_id").is_in(set(user_id_splits[_chunk])))
    df_history_chunk = val_history.filter(pl.col("user_id").is_in(set(user_id_splits[_chunk])))
    df_chunk = create_feature(df_chunk,df_history_chunk,mode='valid')
    
    df_chunk.write_parquet(f"./val_large_chunks/val_df_chunk{_chunk}.parquet")
    
    del df_chunk
    import gc; gc.collect()

# %% [markdown]
# # Test

# %%
# Check if the number of rows in test_behaviors is equal to the number of unique combinations of impression_id and user_id
assert len(test_behaviors) == len(test_behaviors.groupby(['impression_id','user_id']).count())

sub_impression = test_behaviors.select(['impression_id','user_id'])

test_behaviors = test_behaviors.with_columns(
    pl.col("article_ids_inview").apply(lambda x: len(x)).alias("count_article_ids_inview"),
)

# Explode article_ids_inview
test_behaviors = test_behaviors.explode("article_ids_inview")
test_behaviors = test_behaviors.with_columns(pl.col("article_ids_inview").alias("article_id"))

# Get unique user_id
test_user = test_behaviors['user_id'].unique().to_numpy()

# %%
n = 100

test_user_list = np.array_split(test_user,n)

sub_df_list = []

for no,user_list in enumerate(test_user_list):
    logger.info(f'no : {no} / num_user: {len(user_list)}')

    _test_df = test_behaviors.filter(pl.col('user_id').is_in(user_list))
    _test_history = test_history.filter(pl.col('user_id').is_in(user_list))

    test_df = create_feature(_test_df,_test_history,mode='test',logging = False)
    
    test_df.write_parquet(f"./test_large_chunks/test_df_chunk{no}.parquet")
    
    del test_df
    import gc; gc.collect()
# Out:
# [2024-06-17 01:33:02,359][INFO] no : 0 / num_user: 8077
# [2024-06-17 01:41:28,538][INFO] no : 1 / num_user: 8077
# [2024-06-17 01:49:45,406][INFO] no : 2 / num_user: 8077
# [2024-06-17 01:58:17,655][INFO] no : 3 / num_user: 8077
# [2024-06-17 02:06:20,325][INFO] no : 4 / num_user: 8077
# [2024-06-17 02:14:46,663][INFO] no : 5 / num_user: 8077
# [2024-06-17 02:22:56,167][INFO] no : 6 / num_user: 8077
# [2024-06-17 02:31:13,071][INFO] no : 7 / num_user: 8077
# [2024-06-17 02:39:29,354][INFO] no : 8 / num_user: 8077
# [2024-06-17 02:47:37,654][INFO] no : 9 / num_user: 8077
# [2024-06-17 02:55:59,123][INFO] no : 10 / num_user: 8077
# [2024-06-17 03:03:55,807][INFO] no : 11 / num_user: 8077
# [2024-06-17 03:12:33,906][INFO] no : 12 / num_user: 8077
# [2024-06-17 03:20:33,464][INFO] no : 13 / num_user: 8077
# [2024-06-17 03:28:48,979][INFO] no : 14 / num_user: 8077
# [2024-06-17 03:36:46,328][INFO] no : 15 / num_user: 8077
# [2024-06-17 03:44:33,830][INFO] no : 16 / num_user: 8077
# [2024-06-17 03:52:23,390][INFO] no : 17 / num_user: 8077
# [2024-06-17 04:00:44,626][INFO] no : 18 / num_user: 8077
# [2024-06-17 04:08:42,439][INFO] no : 19 / num_user: 8077
# [2024-06-17 04:16:42,442][INFO] no : 20 / num_user: 8077
# [2024-06-17 04:24:44,094][INFO] no : 21 / num_user: 8077
# [2024-06-17 04:33:02,148][INFO] no : 22 / num_user: 8077
# [2024-06-17 04:41:13,958][INFO] no : 23 / num_user: 8077
# [2024-06-17 04:49:19,070][INFO] no : 24 / num_user: 8077
# [2024-06-17 04:57:42,508][INFO] no : 25 / num_user: 8077
# [2024-06-17 05:06:09,404][INFO] no : 26 / num_user: 8077
# [2024-06-17 05:14:31,977][INFO] no : 27 / num_user: 8077
# [2024-06-17 05:22:37,833][INFO] no : 28 / num_user: 8077
# [2024-06-17 05:31:06,766][INFO] no : 29 / num_user: 8077
# [2024-06-17 05:39:30,531][INFO] no : 30 / num_user: 8077
# [2024-06-17 05:47:27,643][INFO] no : 31 / num_user: 8077
# [2024-06-17 05:55:48,473][INFO] no : 32 / num_user: 8077
# [2024-06-17 06:03:59,059][INFO] no : 33 / num_user: 8077
# [2024-06-17 06:12:19,825][INFO] no : 34 / num_user: 8077
# [2024-06-17 06:20:11,736][INFO] no : 35 / num_user: 8077
# [2024-06-17 06:27:59,804][INFO] no : 36 / num_user: 8077
# [2024-06-17 06:36:23,725][INFO] no : 37 / num_user: 8077
# [2024-06-17 06:44:43,767][INFO] no : 38 / num_user: 8077
# [2024-06-17 06:53:13,832][INFO] no : 39 / num_user: 8077
# [2024-06-17 07:01:53,412][INFO] no : 40 / num_user: 8077
# [2024-06-17 07:10:26,612][INFO] no : 41 / num_user: 8077
# [2024-06-17 07:19:11,131][INFO] no : 42 / num_user: 8077
# [2024-06-17 07:27:58,213][INFO] no : 43 / num_user: 8077
# [2024-06-17 07:36:34,912][INFO] no : 44 / num_user: 8077
# [2024-06-17 07:44:42,437][INFO] no : 45 / num_user: 8077
# [2024-06-17 07:53:07,925][INFO] no : 46 / num_user: 8077
# [2024-06-17 08:01:27,054][INFO] no : 47 / num_user: 8077
# [2024-06-17 08:10:03,160][INFO] no : 48 / num_user: 8077
# [2024-06-17 08:18:39,984][INFO] no : 49 / num_user: 8077
# [2024-06-17 08:27:23,978][INFO] no : 50 / num_user: 8077
# [2024-06-17 08:35:52,122][INFO] no : 51 / num_user: 8077
# [2024-06-17 08:44:33,804][INFO] no : 52 / num_user: 8077
# [2024-06-17 08:53:05,925][INFO] no : 53 / num_user: 8077
# [2024-06-17 09:02:02,086][INFO] no : 54 / num_user: 8077
# [2024-06-17 09:10:46,286][INFO] no : 55 / num_user: 8077
# [2024-06-17 09:18:37,479][INFO] no : 56 / num_user: 8077
# [2024-06-17 09:25:58,624][INFO] no : 57 / num_user: 8077
# [2024-06-17 09:33:21,732][INFO] no : 58 / num_user: 8077
# [2024-06-17 09:40:43,123][INFO] no : 59 / num_user: 8077
# [2024-06-17 09:48:13,437][INFO] no : 60 / num_user: 8077
# [2024-06-17 09:55:31,520][INFO] no : 61 / num_user: 8077
# [2024-06-17 10:02:46,944][INFO] no : 62 / num_user: 8077
# [2024-06-17 10:09:58,897][INFO] no : 63 / num_user: 8077
# [2024-06-17 10:17:05,690][INFO] no : 64 / num_user: 8077
# [2024-06-17 10:24:16,319][INFO] no : 65 / num_user: 8077
# [2024-06-17 10:31:32,390][INFO] no : 66 / num_user: 8077
# [2024-06-17 10:38:52,929][INFO] no : 67 / num_user: 8077
# [2024-06-17 10:46:04,486][INFO] no : 68 / num_user: 8077
# [2024-06-17 10:53:24,329][INFO] no : 69 / num_user: 8077
# [2024-06-17 11:00:31,498][INFO] no : 70 / num_user: 8077
# [2024-06-17 11:07:30,930][INFO] no : 71 / num_user: 8077
# [2024-06-17 11:14:27,341][INFO] no : 72 / num_user: 8077
# [2024-06-17 11:21:19,789][INFO] no : 73 / num_user: 8077
# [2024-06-17 11:28:28,002][INFO] no : 74 / num_user: 8077
# [2024-06-17 11:35:33,882][INFO] no : 75 / num_user: 8077
# [2024-06-17 11:42:17,866][INFO] no : 76 / num_user: 8077
# [2024-06-17 11:49:19,330][INFO] no : 77 / num_user: 8076
# [2024-06-17 11:56:25,278][INFO] no : 78 / num_user: 8076
# [2024-06-17 12:03:16,131][INFO] no : 79 / num_user: 8076
# [2024-06-17 12:10:38,614][INFO] no : 80 / num_user: 8076
# [2024-06-17 12:19:00,568][INFO] no : 81 / num_user: 8076
# [2024-06-17 12:28:04,328][INFO] no : 82 / num_user: 8076
# [2024-06-17 12:36:42,150][INFO] no : 83 / num_user: 8076
# [2024-06-17 12:45:04,828][INFO] no : 84 / num_user: 8076
# [2024-06-17 12:53:27,445][INFO] no : 85 / num_user: 8076
# [2024-06-17 13:02:09,087][INFO] no : 86 / num_user: 8076
# [2024-06-17 13:10:37,422][INFO] no : 87 / num_user: 8076
# [2024-06-17 13:19:19,116][INFO] no : 88 / num_user: 8076
# [2024-06-17 13:27:37,496][INFO] no : 89 / num_user: 8076
# [2024-06-17 13:36:06,963][INFO] no : 90 / num_user: 8076
# [2024-06-17 13:44:30,450][INFO] no : 91 / num_user: 8076
# [2024-06-17 13:52:51,731][INFO] no : 92 / num_user: 8076
# [2024-06-17 14:01:36,000][INFO] no : 93 / num_user: 8076
# [2024-06-17 14:11:35,022][INFO] no : 94 / num_user: 8076
# [2024-06-17 14:21:25,257][INFO] no : 95 / num_user: 8076
# [2024-06-17 14:31:10,755][INFO] no : 96 / num_user: 8076
# [2024-06-17 14:40:15,633][INFO] no : 97 / num_user: 8076
# [2024-06-17 14:49:19,121][INFO] no : 98 / num_user: 8076
# [2024-06-17 14:58:55,614][INFO] no : 99 / num_user: 8076
